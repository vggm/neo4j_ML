# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load Data

# %%
data = pd.read_csv("Best_Books_Ever.csv")
print(data.columns)
# data
# Out:
# Index(['bookId', 'title', 'series', 'author', 'rating', 'description',
#        'language', 'isbn', 'genres', 'characters', 'bookFormat', 'edition',
#        'pages', 'publisher', 'publishDate', 'firstPublishDate', 'awards',
#        'numRatings', 'ratingsByStars', 'likedPercent', 'setting', 'coverImg',
#        'bbeScore', 'bbeVotes', 'price'],
#       dtype='object')

# %% [markdown]
# ## Drop Unnecesary Columns And Change NaN to self-concluding when a book doesnt belong to a serie

# %%
data_col_dropped = data.drop("characters", axis=1).drop("numRatings", axis=1).drop("publisher", axis=1).drop("bbeScore", axis=1).drop("bbeVotes", axis=1).drop("bookFormat", axis=1).drop("firstPublishDate", axis=1).drop("description", axis=1).drop("bookId", axis=1).drop("isbn", axis=1).drop("edition", axis=1).drop("awards", axis=1).drop("ratingsByStars", axis=1).drop("setting", axis=1).drop("coverImg", axis=1)
data_col_dropped["series"] = data_col_dropped["series"].fillna('self-concluding')
data_col_dropped
# Out:
#                                            title                 series  \
# 0                               The Hunger Games    The Hunger Games #1
# 1      Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                          To Kill a Mockingbird  To Kill a Mockingbird
# 3                            Pride and Prejudice        self-concluding
# 4                                       Twilight   The Twilight Saga #1
# ...                                          ...                    ...
# 52473                                  Fractured             Fateful #2
# 52474                                    Anasazi      Sense of Truth #2
# 52475                                     Marked      Soul Guardians #1
# 52476                                Wayward Son        self-concluding
# 52477                        Daughter of Helaman   Stripling Warrior #1
#
#                                                   author  rating language  \
# 0                                        Suzanne Collins    4.33  English
# 1              J.K. Rowling, Mary GrandPré (Illustrator)    4.50  English
# 2                                             Harper Lee    4.28  English
# 3              Jane Austen, Anna Quindlen (Introduction)    4.26  English
# 4                                        Stephenie Meyer    3.60  English
# ...                                                  ...     ...      ...
# 52473                   Cheri Schmidt (Goodreads Author)    4.00  English
# 52474                                      Emma Michaels    4.19  English
# 52475                  Kim Richardson (Goodreads Author)    3.70  English
# 52476  Tom Pollack (Goodreads Author), John Loftus (G...    3.85  English
# 52477                    Misty Moncur (Goodreads Author)    4.02  English
#
#                                                   genres pages  \
# 0      ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...   374
# 1      ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...   870
# 2      ['Classics', 'Fiction', 'Historical Fiction', ...   324
# 3      ['Classics', 'Fiction', 'Romance', 'Historical...   279
# 4      ['Young Adult', 'Fantasy', 'Romance', 'Vampire...   501
# ...                                                  ...   ...
# 52473  ['Vampires', 'Paranormal', 'Young Adult', 'Rom...     0
# 52474                         ['Mystery', 'Young Adult']   190
# 52475  ['Fantasy', 'Young Adult', 'Paranormal', 'Ange...   280
# 52476  ['Fiction', 'Mystery', 'Historical Fiction', '...   507
# 52477  ['Lds Fiction', 'Historical Fiction', 'Young A...   201
#
#               publishDate  likedPercent price
# 0                09/14/08          96.0  5.09
# 1                09/28/04          98.0  7.38
# 2                05/23/06          95.0   NaN
# 3                10/10/00          94.0   NaN
# 4                09/06/06          78.0   2.1
# ...                   ...           ...   ...
# 52473       May 28th 2011          94.0   NaN
# 52474     August 5th 2011          95.0   NaN
# 52475     March 18th 2011          84.0  7.37
# 52476  September 1st 2011          90.0  2.86
# 52477        May 8th 2011          90.0  5.20
#
# [52478 rows x 10 columns]

# %% [markdown]
# ## Simple Query to search by author

# %%
data_col_dropped[data_col_dropped["author"].str.contains("Patrick Rothfuss", case=False, na=False)].sort_values("likedPercent", ascending=False)
# Out:
#                                   title  \
# 308                 The Wise Man's Fear
# 15033   O Medo do Homem Sábio - Parte 1
# 15429   O Medo do Homem Sábio - Parte 2
# 110                The Name of the Wind
# 21087               Tuule nimi I raamat
# 2385   The Slow Regard of Silent Things
# 16385                    Doors of Stone
#
#                                          series  \
# 308                 The Kingkiller Chronicle #2
# 15033  The Kingkiller Chronicle #2, Part 1 of 2
# 15429  The Kingkiller Chronicle #2, Part 2 of 2
# 110                 The Kingkiller Chronicle #1
# 21087  The Kingkiller Chronicle #1, Part 1 of 2
# 2385              The Kingkiller Chronicle #2.5
# 16385               The Kingkiller Chronicle #3
#
#                                                   author  rating    language  \
# 308                  Patrick Rothfuss (Goodreads Author)    4.56     English
# 15033  Patrick Rothfuss (Goodreads Author), Renato Ca...    4.52  Portuguese
# 15429  Patrick Rothfuss (Goodreads Author), Renato Ca...    4.48  Portuguese
# 110                  Patrick Rothfuss (Goodreads Author)    4.53     English
# 21087  Patrick Rothfuss (Goodreads Author), Juhan Hab...    4.21    Estonian
# 2385   Patrick Rothfuss (Goodreads Author), Nate Tayl...    3.90     English
# 16385                Patrick Rothfuss (Goodreads Author)    3.72     English
#
#                                                   genres pages  \
# 308    ['Fantasy', 'Fiction', 'Epic Fantasy', 'High F...   994
# 15033  ['Fantasy', 'High Fantasy', 'Epic Fantasy', 'F...   703
# 15429  ['Fantasy', 'High Fantasy', 'Epic Fantasy', 'F...   684
# 110    ['Fantasy', 'Fiction', 'Epic Fantasy', 'High F...   662
# 21087  ['Fantasy', 'Adventure', 'Fiction', 'Young Adu...   367
# 2385   ['Fantasy', 'Fiction', 'Short Stories', 'High ...   159
# 16385  ['Fantasy', 'Fiction', 'Epic Fantasy', 'High F...   NaN
#
#                publishDate  likedPercent   price
# 308               03/01/11          98.0   16.37
# 15033  September 21st 2011          98.0  254.45
# 15429   November 28th 2011          97.0  254.45
# 110               04/28/07          96.0    9.36
# 21087                 2008          93.0     NaN
# 2385     October 28th 2014          89.0    9.58
# 16385            Published          73.0     NaN

# %% [markdown]
# #### Simple method to extract author

# %%
def extract_author(authors: str) -> str:
  author = authors.split(', ')[0]
  if "(" not in author:
    return author
  else:
    return author.split(' (')[0]

# %% [markdown]
# ## Simplify authors

# %%
data_col_dropped["author"] = data_col_dropped["author"].apply(extract_author)
data_col_dropped
# Out:
#                                            title                 series  \
# 0                               The Hunger Games    The Hunger Games #1
# 1      Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                          To Kill a Mockingbird  To Kill a Mockingbird
# 3                            Pride and Prejudice        self-concluding
# 4                                       Twilight   The Twilight Saga #1
# ...                                          ...                    ...
# 52473                                  Fractured             Fateful #2
# 52474                                    Anasazi      Sense of Truth #2
# 52475                                     Marked      Soul Guardians #1
# 52476                                Wayward Son        self-concluding
# 52477                        Daughter of Helaman   Stripling Warrior #1
#
#                 author  rating language  \
# 0      Suzanne Collins    4.33  English
# 1         J.K. Rowling    4.50  English
# 2           Harper Lee    4.28  English
# 3          Jane Austen    4.26  English
# 4      Stephenie Meyer    3.60  English
# ...                ...     ...      ...
# 52473    Cheri Schmidt    4.00  English
# 52474    Emma Michaels    4.19  English
# 52475   Kim Richardson    3.70  English
# 52476      Tom Pollack    3.85  English
# 52477     Misty Moncur    4.02  English
#
#                                                   genres pages  \
# 0      ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...   374
# 1      ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...   870
# 2      ['Classics', 'Fiction', 'Historical Fiction', ...   324
# 3      ['Classics', 'Fiction', 'Romance', 'Historical...   279
# 4      ['Young Adult', 'Fantasy', 'Romance', 'Vampire...   501
# ...                                                  ...   ...
# 52473  ['Vampires', 'Paranormal', 'Young Adult', 'Rom...     0
# 52474                         ['Mystery', 'Young Adult']   190
# 52475  ['Fantasy', 'Young Adult', 'Paranormal', 'Ange...   280
# 52476  ['Fiction', 'Mystery', 'Historical Fiction', '...   507
# 52477  ['Lds Fiction', 'Historical Fiction', 'Young A...   201
#
#               publishDate  likedPercent price
# 0                09/14/08          96.0  5.09
# 1                09/28/04          98.0  7.38
# 2                05/23/06          95.0   NaN
# 3                10/10/00          94.0   NaN
# 4                09/06/06          78.0   2.1
# ...                   ...           ...   ...
# 52473       May 28th 2011          94.0   NaN
# 52474     August 5th 2011          95.0   NaN
# 52475     March 18th 2011          84.0  7.37
# 52476  September 1st 2011          90.0  2.86
# 52477        May 8th 2011          90.0  5.20
#
# [52478 rows x 10 columns]

# %% [markdown]
# #### Simple method to clean series

# %%
def clean_series(series: str) -> str:
  if "#" in series:
    return series.split(' #')[0]
  return series

# %% [markdown]
# ## Clean series

# %%
data_col_dropped["series"] = data_col_dropped["series"].apply(clean_series)
data_col_dropped
# Out:
#                                            title                 series  \
# 0                               The Hunger Games       The Hunger Games
# 1      Harry Potter and the Order of the Phoenix           Harry Potter
# 2                          To Kill a Mockingbird  To Kill a Mockingbird
# 3                            Pride and Prejudice        self-concluding
# 4                                       Twilight      The Twilight Saga
# ...                                          ...                    ...
# 52473                                  Fractured                Fateful
# 52474                                    Anasazi         Sense of Truth
# 52475                                     Marked         Soul Guardians
# 52476                                Wayward Son        self-concluding
# 52477                        Daughter of Helaman      Stripling Warrior
#
#                 author  rating language  \
# 0      Suzanne Collins    4.33  English
# 1         J.K. Rowling    4.50  English
# 2           Harper Lee    4.28  English
# 3          Jane Austen    4.26  English
# 4      Stephenie Meyer    3.60  English
# ...                ...     ...      ...
# 52473    Cheri Schmidt    4.00  English
# 52474    Emma Michaels    4.19  English
# 52475   Kim Richardson    3.70  English
# 52476      Tom Pollack    3.85  English
# 52477     Misty Moncur    4.02  English
#
#                                                   genres pages  \
# 0      ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...   374
# 1      ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...   870
# 2      ['Classics', 'Fiction', 'Historical Fiction', ...   324
# 3      ['Classics', 'Fiction', 'Romance', 'Historical...   279
# 4      ['Young Adult', 'Fantasy', 'Romance', 'Vampire...   501
# ...                                                  ...   ...
# 52473  ['Vampires', 'Paranormal', 'Young Adult', 'Rom...     0
# 52474                         ['Mystery', 'Young Adult']   190
# 52475  ['Fantasy', 'Young Adult', 'Paranormal', 'Ange...   280
# 52476  ['Fiction', 'Mystery', 'Historical Fiction', '...   507
# 52477  ['Lds Fiction', 'Historical Fiction', 'Young A...   201
#
#               publishDate  likedPercent price
# 0                09/14/08          96.0  5.09
# 1                09/28/04          98.0  7.38
# 2                05/23/06          95.0   NaN
# 3                10/10/00          94.0   NaN
# 4                09/06/06          78.0   2.1
# ...                   ...           ...   ...
# 52473       May 28th 2011          94.0   NaN
# 52474     August 5th 2011          95.0   NaN
# 52475     March 18th 2011          84.0  7.37
# 52476  September 1st 2011          90.0  2.86
# 52477        May 8th 2011          90.0  5.20
#
# [52478 rows x 10 columns]

# %% [markdown]
# ## Extract every author

# %%
authors = set()
for book in data_col_dropped.values:
  book_authors : str = book[2]
  for author in book_authors.split(', '):
    if "(" in author and "(Goodreads Author)" not in author:
      continue
    authors.add(author.removesuffix(" (Goodreads Author)"))
print(f'Total Authors: {len(authors)}')
# Out:
# Total Authors: 23195

# %% [markdown]
# ## Simple example that show every book from a random author

# %%
from random import choice as rdc
author = rdc(list(authors))
print(author)
data_col_dropped[data_col_dropped["author"].str.contains(author, case=False, na=False)]
# Out:
# Pavol Rankov
#                                                    title           series  \
# 35319  Zdarzyło się pierwszego września (albo kiedy i...  self-concluding
#
#              author  rating language  \
# 35319  Pavol Rankov    4.21   Polish
#
#                                                   genres pages publishDate  \
# 35319  ['Historical Fiction', 'Fiction', 'War', 'Czec...   468        2013
#
#        likedPercent price
# 35319          97.0   NaN

# %% [markdown]
# ### Drop every row that has some NaN or null features and filter books that are in English and from them, remove books that doesnt have any genre

# %%
data_NaN_dropped = data_col_dropped.dropna()
data_english_sorted = data_NaN_dropped[(data_NaN_dropped["language"] == "English")]
data_genres_not_empty = data_english_sorted[data_english_sorted["genres"].apply(lambda x: x.removeprefix('[').removesuffix(']') != '')]
data_genres_not_empty
# Out:
#                                            title             series  \
# 0                               The Hunger Games   The Hunger Games
# 1      Harry Potter and the Order of the Phoenix       Harry Potter
# 4                                       Twilight  The Twilight Saga
# 5                                 The Book Thief    self-concluding
# 6                                    Animal Farm    self-concluding
# ...                                          ...                ...
# 52470                          Attracted to Fire    self-concluding
# 52472                               Unbelievable          Port Fare
# 52475                                     Marked     Soul Guardians
# 52476                                Wayward Son    self-concluding
# 52477                        Daughter of Helaman  Stripling Warrior
#
#                 author  rating language  \
# 0      Suzanne Collins    4.33  English
# 1         J.K. Rowling    4.50  English
# 4      Stephenie Meyer    3.60  English
# 5         Markus Zusak    4.37  English
# 6        George Orwell    3.95  English
# ...                ...     ...      ...
# 52470      DiAnn Mills    4.14  English
# 52472    Sherry Gammon    4.16  English
# 52475   Kim Richardson    3.70  English
# 52476      Tom Pollack    3.85  English
# 52477     Misty Moncur    4.02  English
#
#                                                   genres pages  \
# 0      ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...   374
# 1      ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...   870
# 4      ['Young Adult', 'Fantasy', 'Romance', 'Vampire...   501
# 5      ['Historical Fiction', 'Fiction', 'Young Adult...   552
# 6      ['Classics', 'Fiction', 'Dystopia', 'Fantasy',...   141
# ...                                                  ...   ...
# 52470  ['Christian Fiction', 'Christian', 'Suspense',...   416
# 52472  ['Romance', 'Young Adult', 'Contemporary', 'Co...   360
# 52475  ['Fantasy', 'Young Adult', 'Paranormal', 'Ange...   280
# 52476  ['Fiction', 'Mystery', 'Historical Fiction', '...   507
# 52477  ['Lds Fiction', 'Historical Fiction', 'Young A...   201
#
#               publishDate  likedPercent  price
# 0                09/14/08          96.0   5.09
# 1                09/28/04          98.0   7.38
# 4                09/06/06          78.0    2.1
# 5                03/14/06          96.0    3.8
# 6                04/28/96          91.0   4.42
# ...                   ...           ...    ...
# 52470    October 1st 2011          95.0   5.55
# 52472     April 11th 2013          94.0  19.18
# 52475     March 18th 2011          84.0   7.37
# 52476  September 1st 2011          90.0   2.86
# 52477        May 8th 2011          90.0   5.20
#
# [31961 rows x 10 columns]

# %% [markdown]
# #### Simple function made to extract the year from a date

# %%
def extract_year_from_date(date: str) -> str:
  if "/" in date:
    year = date[-2:]
    return f"20{year}" if int(year) < 24 else f"19{year}"
  else:
    return date[-4:]

# %% [markdown]
# ## Create the column Publish Year and extract the year from Publish Date

# %%
data_genres_not_empty['publishYear'] = data_genres_not_empty['publishDate'].apply(extract_year_from_date)
data_genres_not_empty = data_genres_not_empty[['title', 'series', 'author', 'language', 'genres', 'pages', 'publishDate', 'publishYear', 'rating', 'likedPercent', 'price']]
data_genres_not_empty
# Out:
# C:\Users\victo\AppData\Local\Temp\ipykernel_9884\1559170351.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_genres_not_empty['publishYear'] = data_genres_not_empty['publishDate'].apply(extract_year_from_date)
#                                            title             series  \
# 0                               The Hunger Games   The Hunger Games
# 1      Harry Potter and the Order of the Phoenix       Harry Potter
# 4                                       Twilight  The Twilight Saga
# 5                                 The Book Thief    self-concluding
# 6                                    Animal Farm    self-concluding
# ...                                          ...                ...
# 52470                          Attracted to Fire    self-concluding
# 52472                               Unbelievable          Port Fare
# 52475                                     Marked     Soul Guardians
# 52476                                Wayward Son    self-concluding
# 52477                        Daughter of Helaman  Stripling Warrior
#
#                 author language  \
# 0      Suzanne Collins  English
# 1         J.K. Rowling  English
# 4      Stephenie Meyer  English
# 5         Markus Zusak  English
# 6        George Orwell  English
# ...                ...      ...
# 52470      DiAnn Mills  English
# 52472    Sherry Gammon  English
# 52475   Kim Richardson  English
# 52476      Tom Pollack  English
# 52477     Misty Moncur  English
#
#                                                   genres pages  \
# 0      ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...   374
# 1      ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...   870
# 4      ['Young Adult', 'Fantasy', 'Romance', 'Vampire...   501
# 5      ['Historical Fiction', 'Fiction', 'Young Adult...   552
# 6      ['Classics', 'Fiction', 'Dystopia', 'Fantasy',...   141
# ...                                                  ...   ...
# 52470  ['Christian Fiction', 'Christian', 'Suspense',...   416
# 52472  ['Romance', 'Young Adult', 'Contemporary', 'Co...   360
# 52475  ['Fantasy', 'Young Adult', 'Paranormal', 'Ange...   280
# 52476  ['Fiction', 'Mystery', 'Historical Fiction', '...   507
# 52477  ['Lds Fiction', 'Historical Fiction', 'Young A...   201
#
#               publishDate publishYear  rating  likedPercent  price
# 0                09/14/08        2008    4.33          96.0   5.09
# 1                09/28/04        2004    4.50          98.0   7.38
# 4                09/06/06        2006    3.60          78.0    2.1
# 5                03/14/06        2006    4.37          96.0    3.8
# 6                04/28/96        1996    3.95          91.0   4.42
# ...                   ...         ...     ...           ...    ...
# 52470    October 1st 2011        2011    4.14          95.0   5.55
# 52472     April 11th 2013        2013    4.16          94.0  19.18
# 52475     March 18th 2011        2011    3.70          84.0   7.37
# 52476  September 1st 2011        2011    3.85          90.0   2.86
# 52477        May 8th 2011        2011    4.02          90.0   5.20
#
# [31961 rows x 11 columns]

# %% [markdown]
# ### To process words in ML they have to be remplaced by numbers, so to reach that, we need to associate a word to a number

# %% [markdown]
# #### Genre to Number and vice versa

# %%
genre_to_num = {}
num_to_genre = {}

total_genres = 0
visited = set()

for genres in data_genres_not_empty["genres"]:
  list_of_genres = genres.removeprefix('[').removesuffix(']').split(', ')
  for genre in list_of_genres:
    if genre not in visited:
      genre_cleanned = genre[1:][:-1]
      num_to_genre[total_genres] = genre_cleanned
      genre_to_num[genre_cleanned] = total_genres
      total_genres += 1
      visited.add(genre)

print(f'Total Genres: {total_genres}')
num_to_genre
# Out:
# Total Genres: 944
# {0: 'Young Adult',
#  1: 'Fiction',
#  2: 'Dystopia',
#  3: 'Fantasy',
#  4: 'Science Fiction',
#  5: 'Romance',
#  6: 'Adventure',
#  7: 'Teen',
#  8: 'Post Apocalyptic',
#  9: 'Action',
#  10: 'Magic',
#  11: 'Childrens',
#  12: 'Audiobook',
#  13: 'Middle Grade',
#  14: 'Classics',
#  15: 'Science Fiction Fantasy',
#  16: 'Vampires',
#  17: 'Paranormal',
#  18: 'Paranormal Romance',
#  19: 'Supernatural',
#  20: 'Urban Fantasy',
#  21: 'Historical Fiction',
#  22: 'Historical',
#  23: 'War',
#  24: 'Holocaust',
#  25: 'World War II',
#  26: 'Books About Books',
#  27: 'Literature',
#  28: 'Politics',
#  29: 'School',
#  30: 'Novels',
#  31: 'Read For School',
#  32: 'Epic Fantasy',
#  33: 'High Fantasy',
#  34: 'Civil War',
#  35: 'Historical Romance',
#  36: 'Picture Books',
#  37: 'Poetry',
#  38: 'Juvenile',
#  39: 'Kids',
#  40: 'Short Stories',
#  41: 'Gothic',
#  42: '19th Century',
#  43: 'Classic Literature',
#  44: 'Japan',
#  45: 'Adult',
#  46: 'Asia',
#  47: 'Adult Fiction',
#  48: 'British Literature',
#  49: 'High School',
#  50: 'Plays',
#  51: 'Drama',
#  52: 'Philosophy',
#  53: 'Spirituality',
#  54: 'Self Help',
#  55: 'Inspirational',
#  56: 'Russia',
#  57: 'Russian Literature',
#  58: 'Crime',
#  59: 'Angels',
#  60: 'Canada',
#  61: 'Coming Of Age',
#  62: 'Animals',
#  63: 'Chapter Books',
#  64: 'American',
#  65: 'Horror',
#  66: 'Humor',
#  67: 'Comedy',
#  68: 'Fairy Tales',
#  69: 'Mythology',
#  70: 'Greek Mythology',
#  71: 'Contemporary',
#  72: 'Time Travel',
#  73: 'Dragons',
#  74: 'Epic',
#  75: 'Mystery',
#  76: 'Monsters',
#  77: 'Food',
#  78: 'Magical Realism',
#  79: 'India',
#  80: 'Book Club',
#  81: 'Unfinished',
#  82: 'Space Opera',
#  83: 'Thriller',
#  84: 'Apocalyptic',
#  85: 'Victorian',
#  86: 'Scotland',
#  87: 'Chick Lit',
#  88: 'Realistic Fiction',
#  89: 'Family',
#  90: 'Feminism',
#  91: 'LGBT',
#  92: 'African American',
#  93: 'New York',
#  94: 'Modern Classics',
#  95: 'Religion',
#  96: 'Nonfiction',
#  97: 'Memoir',
#  98: 'Biography',
#  99: 'Ireland',
#  100: 'Autobiography',
#  101: 'Biography Memoir',
#  102: 'History',
#  103: 'Irish Literature',
#  104: 'Africa',
#  105: 'Literary Fiction',
#  106: 'Steampunk',
#  107: 'Spanish Literature',
#  108: 'Spain',
#  109: 'Economics',
#  110: '20th Century',
#  111: 'Womens',
#  112: 'Mystery Thriller',
#  113: 'Suspense',
#  114: 'Queer',
#  115: 'Young Adult Fantasy',
#  116: 'Travel',
#  117: 'Psychology',
#  118: 'Counting',
#  119: 'Storytime',
#  120: 'Mathematics',
#  121: 'Czech Literature',
#  122: 'Italian Literature',
#  123: 'Italy',
#  124: 'True Crime',
#  125: 'Cats',
#  126: 'France',
#  127: 'Westerns',
#  128: 'German Literature',
#  129: 'Graphic Novels',
#  130: 'Comics',
#  131: 'Graphic Novels Comics',
#  132: 'Comic Book',
#  133: 'Superheroes',
#  134: 'World War I',
#  135: 'Theatre',
#  136: 'Environment',
#  137: 'China',
#  138: 'Sweden',
#  139: 'Pirates',
#  140: 'Medieval',
#  141: 'Retellings',
#  142: 'Witches',
#  143: 'Japanese Literature',
#  144: 'Detective',
#  145: 'Media Tie In',
#  146: 'Biblical Fiction',
#  147: 'Biblical',
#  148: 'Indian Literature',
#  149: 'Art',
#  150: 'Christian',
#  151: 'Banned Books',
#  152: 'Werewolves',
#  153: 'Mental Illness',
#  154: 'Dogs',
#  155: 'Journalism',
#  156: 'Latin American',
#  157: 'Comic Strips',
#  158: 'Race',
#  159: 'Speculative Fiction',
#  160: 'Love',
#  161: 'Tragedy',
#  162: 'Egypt',
#  163: 'Ancient History',
#  164: 'Young Adult Contemporary',
#  165: 'Mental Health',
#  166: 'Abuse',
#  167: 'Arthurian',
#  168: 'Nature',
#  169: 'Survival',
#  170: 'French Literature',
#  171: '18th Century',
#  172: 'Travelogue',
#  173: 'Reference',
#  174: 'Space',
#  175: 'Military Fiction',
#  176: 'Anthologies',
#  177: 'Childrens Classics',
#  178: 'Scandinavian Literature',
#  179: 'Southern',
#  180: 'Erotica',
#  181: 'BDSM',
#  182: 'Contemporary Romance',
#  183: 'Erotic Romance',
#  184: 'Cyberpunk',
#  185: 'English Literature',
#  186: 'South Africa',
#  187: 'Christian Fiction',
#  188: 'Science',
#  189: 'Popular Science',
#  190: 'Physics',
#  191: 'Music',
#  192: 'Death',
#  193: 'Horses',
#  194: 'Ghosts',
#  195: 'Regency',
#  196: 'Germany',
#  197: 'Southern Gothic',
#  198: 'Jewish',
#  199: 'True Story',
#  200: 'Taoism',
#  201: 'Eastern Philosophy',
#  202: 'Legal Thriller',
#  203: 'Law',
#  204: 'Biology',
#  205: 'Evolution',
#  206: 'Anthropology',
#  207: 'Political Science',
#  208: 'Young Adult Romance',
#  209: 'Futuristic',
#  210: 'Judaism',
#  211: 'Swedish Literature',
#  212: 'American History',
#  213: 'Faith',
#  214: 'Christian Romance',
#  215: 'Aliens',
#  216: 'New Adult',
#  217: 'Fae',
#  218: 'College',
#  219: 'Robots',
#  220: 'Essays',
#  221: 'Ancient',
#  222: 'Dark',
#  223: 'Fairies',
#  224: 'Folklore',
#  225: 'Atheism',
#  226: 'Theology',
#  227: 'Zombies',
#  228: 'Education',
#  229: 'Pakistan',
#  230: 'The United States Of America',
#  231: 'Christmas',
#  232: 'Holiday',
#  233: 'Demons',
#  234: 'Mountaineering',
#  235: 'Sports',
#  236: 'Christianity',
#  237: 'Medicine',
#  238: 'Ethiopia',
#  239: 'Medical',
#  240: 'Theory',
#  241: 'Academic',
#  242: 'Unicorns',
#  243: 'Business',
#  244: 'Leadership',
#  245: 'Alternate History',
#  246: 'Horse Racing',
#  247: 'American Civil War',
#  248: 'Espionage',
#  249: 'Social Justice',
#  250: 'Astronomy',
#  251: 'Presidents',
#  252: 'American Revolution',
#  253: 'Greece',
#  254: 'Nobel Prize',
#  255: 'Lds',
#  256: 'Church',
#  257: 'Noir',
#  258: 'Native Americans',
#  259: 'Writing',
#  260: 'Botswana',
#  261: 'Love Story',
#  262: 'Road Trip',
#  263: 'Sociology',
#  264: 'Finance',
#  265: 'Social Science',
#  266: 'Health',
#  267: 'Nutrition',
#  268: 'Cooking',
#  269: 'Disability',
#  270: 'Halloween',
#  271: 'Aviation',
#  272: 'Romanticism',
#  273: 'Collections',
#  274: 'Israel',
#  275: 'European History',
#  276: 'Personal Development',
#  277: 'Productivity',
#  278: 'Management',
#  279: 'Australia',
#  280: 'Fighters',
#  281: 'Psychological Thriller',
#  282: 'Liberia',
#  283: 'Sierra Leone',
#  284: 'Art History',
#  285: 'Beauty and The Beast',
#  286: 'Fairy Tale Retellings',
#  287: 'Outdoors',
#  288: 'Roman',
#  289: 'Murder Mystery',
#  290: 'Shapeshifters',
#  291: 'Architecture',
#  292: 'Hinduism',
#  293: 'Animal Fiction',
#  294: 'Gay',
#  295: 'M M Romance',
#  296: 'Brazil',
#  297: 'Denmark',
#  298: 'Danish',
#  299: 'Fashion',
#  300: 'Computer Science',
#  301: 'Asian Literature',
#  302: 'Cults',
#  303: 'Prehistoric',
#  304: 'Latin American Literature',
#  305: 'Weird Fiction',
#  306: 'Lovecraftian',
#  307: 'Cultural',
#  308: 'Dark Fantasy',
#  309: 'Canadian Literature',
#  310: 'Iran',
#  311: '14th Century',
#  312: 'Historical Mystery',
#  313: 'Batman',
#  314: 'Dc Comics',
#  315: 'Americana',
#  316: 'Genetics',
#  317: 'Emotion',
#  318: 'New Age',
#  319: 'Polish Literature',
#  320: 'Womens Fiction',
#  321: 'New Weird',
#  322: 'Hugo Awards',
#  323: 'Sudan',
#  324: 'Diary',
#  325: 'Buisness',
#  326: 'Christian Non Fiction',
#  327: 'Tudor Period',
#  328: 'Money',
#  329: 'Personal Finance',
#  330: 'Entrepreneurship',
#  331: 'Buddhism',
#  332: 'Baseball',
#  333: 'Novella',
#  334: 'Young Adult Paranormal',
#  335: 'Spy Thriller',
#  336: 'Elves',
#  337: '15th Century',
#  338: 'Plantagenet',
#  339: 'Skepticism',
#  340: 'Police',
#  341: 'Catholic',
#  342: 'Archaeology',
#  343: 'Christian Living',
#  344: 'Gardening',
#  345: 'Historical Fantasy',
#  346: 'Conspiracy Theories',
#  347: 'Occult',
#  348: 'Medieval History',
#  349: 'World History',
#  350: 'Nigeria',
#  351: 'African Literature',
#  352: 'Military History',
#  353: 'Ecology',
#  354: 'Sustainability',
#  355: 'Technology',
#  356: 'Utopia',
#  357: 'Kenya',
#  358: 'Language',
#  359: 'Linguistics',
#  360: 'Rabbits',
#  361: 'Serbian Literature',
#  362: 'Relationships',
#  363: 'Marriage',
#  364: 'Communication',
#  365: 'Manga',
#  366: 'Ghost Stories',
#  367: 'Amazon',
#  368: 'Poverty',
#  369: 'Social Issues',
#  370: 'Hard Boiled',
#  371: 'Wolves',
#  372: 'Christian Fantasy',
#  373: 'Aspergers',
#  374: 'Somalia',
#  375: 'Nordic Noir',
#  376: 'Gender',
#  377: 'Gender Studies',
#  378: 'Anime',
#  379: 'Shojo',
#  380: 'Comics Manga',
#  381: 'Counter Culture',
#  382: 'Time Travel Romance',
#  383: 'Lesbian',
#  384: 'Lds Non Fiction',
#  385: 'Young Adult Historical Fiction',
#  386: 'Cartoon',
#  387: 'Dinosaurs',
#  388: '16th Century',
#  389: 'American Revolutionary War',
#  390: 'Poland',
#  391: 'Islam',
#  392: 'Forgotten Realms',
#  393: 'Dungeons and Dragons',
#  394: 'Dragonlance',
#  395: 'Regency Romance',
#  396: 'Geography',
#  397: 'Comic Fantasy',
#  398: 'Chess',
#  399: 'Martial Arts',
#  400: 'Romantic Suspense',
#  401: 'Engineering',
#  402: 'Pop Culture',
#  403: 'Morocco',
#  404: 'Amish',
#  405: 'Wizards',
#  406: 'Comix',
#  407: 'Modern',
#  408: 'Portugal',
#  409: 'Portuguese Literature',
#  410: 'Teaching',
#  411: 'Boarding School',
#  412: 'Cult Classics',
#  413: 'Clean Romance',
#  414: 'Fitness',
#  415: 'Metaphysics',
#  416: 'Fantasy Romance',
#  417: 'Adoption',
#  418: '17th Century',
#  419: 'Natural History',
#  420: 'Pulp',
#  421: 'Mermaids',
#  422: 'Christian Historical Fiction',
#  423: 'Society',
#  424: 'Mormonism',
#  425: 'Neuroscience',
#  426: 'Poetry Plays',
#  427: 'Discipleship',
#  428: '21st Century',
#  429: 'Menage',
#  430: 'Musicians',
#  431: '13th Century',
#  432: 'Short Story Collection',
#  433: 'Walking',
#  434: 'Lebanon',
#  435: 'Egyptian Literature',
#  436: 'Gods',
#  437: 'Mysticism',
#  438: 'Psychoanalysis',
#  439: 'Hard Science Fiction',
#  440: 'Ghana',
#  441: 'Health Care',
#  442: 'Foodie',
#  443: 'Activism',
#  444: 'Urban',
#  445: 'Academia',
#  446: 'Dying Earth',
#  447: 'Fostering',
#  448: 'Rwanda',
#  449: 'Transgender',
#  450: 'Design',
#  451: '12th Century',
#  452: 'Chinese Literature',
#  453: 'Sexuality',
#  454: 'Lds Fiction',
#  455: 'Belgium',
#  456: 'Film',
#  457: 'Medieval Romance',
#  458: 'Romantic',
#  459: 'Ukraine',
#  460: 'Plants',
#  461: 'Anti Racist',
#  462: 'Western Romance',
#  463: 'Hungarian Literature',
#  464: 'Hungary',
#  465: 'Turkish Literature',
#  466: 'Turkish',
#  467: 'Drawing',
#  468: 'How To',
#  469: 'Art Design',
#  470: 'Anglo Saxon',
#  471: 'Hockey',
#  472: 'Video Games',
#  473: 'Gaming',
#  474: 'Games',
#  475: 'Shonen',
#  476: 'Maritime',
#  477: 'Anthropomorphic',
#  478: 'Military Science Fiction',
#  479: 'Logic',
#  480: 'American Fiction',
#  481: 'Sports Romance',
#  482: 'Star Wars',
#  483: 'Cities',
#  484: 'Urban Planning',
#  485: 'Finnish Literature',
#  486: 'Heroic Fantasy',
#  487: 'Sword and Sorcery',
#  488: 'Vegan',
#  489: 'Cozy Mystery',
#  490: 'Deception',
#  491: 'Princesses',
#  492: 'United States',
#  493: 'Bulgaria',
#  494: 'Bulgarian Literature',
#  495: 'Textbooks',
#  496: 'Technical',
#  497: 'Virtual Reality',
#  498: 'Photography',
#  499: 'Criticism',
#  500: 'Harlequin Teen',
#  501: 'Indonesian Literature',
#  502: 'Banks',
#  503: 'Sequential Art',
#  504: 'Rock N Roll',
#  505: 'Cycling',
#  506: 'Russian History',
#  507: 'Guides',
#  508: 'Own',
#  509: 'Superman',
#  510: 'Fandom',
#  511: 'Wicca',
#  512: 'Bande Dessinée',
#  513: 'Josei',
#  514: 'Music Biography',
#  515: 'Queer Lit',
#  516: 'The World',
#  517: 'Programming',
#  518: 'Native American History',
#  519: 'Love Inspired',
#  520: 'Love Inspired Historical',
#  521: 'Literary Criticism',
#  522: 'Parenting',
#  523: 'Journal',
#  524: 'Georgian',
#  525: 'Young Readers',
#  526: 'Wildlife',
#  527: 'Brain',
#  528: 'Lesbian Fiction',
#  529: 'Knitting',
#  530: 'European Literature',
#  531: 'Illness',
#  532: 'Cinderella',
#  533: 'Prostitution',
#  534: 'Divorce',
#  535: 'Social',
#  536: 'Geek',
#  537: 'Computers',
#  538: 'Birds',
#  539: 'Epic Poetry',
#  540: 'Swashbuckling',
#  541: 'Transport',
#  542: 'Government',
#  543: 'God',
#  544: 'Football',
#  545: 'History Of Science',
#  546: 'Counselling',
#  547: 'Romanian Literature',
#  548: 'Romania',
#  549: 'Cthulhu Mythos',
#  550: 'Dictionaries',
#  551: 'Science Fiction Romance',
#  552: 'Journaling',
#  553: 'Crafts',
#  554: 'Dutch Literature',
#  555: 'Prehistory',
#  556: 'Spanish Civil War',
#  557: 'Wilderness',
#  558: 'Number',
#  559: 'International',
#  560: 'Surreal',
#  561: 'Us Presidents',
#  562: 'Naval History',
#  563: 'Cameroon',
#  564: 'Light Novel',
#  565: 'Street Art',
#  566: 'Graffiti',
#  567: 'Terrorism',
#  568: 'Seinen',
#  569: 'Kazakhstan',
#  570: 'Classical Studies',
#  571: 'Satanism',
#  572: 'Polygamy',
#  573: 'Singularity',
#  574: 'Quantum Mechanics',
#  575: 'Artificial Intelligence',
#  576: 'Futurism',
#  577: 'Cookbooks',
#  578: 'Military Romance',
#  579: 'Fat Acceptance',
#  580: 'Fat',
#  581: 'Fat Studies',
#  582: 'Womens Studies',
#  583: 'Anarchism',
#  584: 'Geometry',
#  585: 'Gothic Romance',
#  586: 'Tasmania',
#  587: 'M F Romance',
#  588: 'Humanities',
#  589: 'Basketball',
#  590: 'Recreation',
#  591: 'Female Authors',
#  592: 'Marvel',
#  593: 'Social Work',
#  594: 'Psychiatry',
#  595: 'French Revolution',
#  596: 'X Men',
#  597: 'Fables',
#  598: 'Hackers',
#  599: 'Microhistory',
#  600: 'Elizabethan Period',
#  601: 'Bolivia',
#  602: 'Teachers',
#  603: 'African American Literature',
#  604: 'Climbing',
#  605: 'Soccer',
#  606: 'Sci Fi Fantasy',
#  607: 'Paranormal Mystery',
#  608: 'Class',
#  609: 'Judaica',
#  610: 'Culinary',
#  611: 'Food and Drink',
#  612: 'Zen',
#  613: 'Punk',
#  614: 'Oral History',
#  615: 'Prayer',
#  616: 'Lesbian Romance',
#  617: 'Holland',
#  618: 'Gay Fiction',
#  619: 'Splatterpunk',
#  620: 'Albanian Literature',
#  621: 'Internet',
#  622: 'Urbanism',
#  623: 'Urban Studies',
#  624: 'Jazz',
#  625: 'Paganism',
#  626: 'Church History',
#  627: 'Near Future',
#  628: 'M M F',
#  629: 'Old Testament',
#  630: 'Slice Of Life',
#  631: 'Young Adult Science Fiction',
#  632: 'Chemistry',
#  633: 'M M Fantasy',
#  634: 'Nursery Rhymes',
#  635: 'Thelema',
#  636: 'Magick',
#  637: 'Esoterica',
#  638: 'Research',
#  639: 'Trains',
#  640: 'Puzzles',
#  641: 'Hip Hop',
#  642: 'History and Politics',
#  643: 'Alternate Universe',
#  644: 'Diets',
#  645: 'Bangladesh',
#  646: 'Algeria',
#  647: 'Palaeontology',
#  648: 'Science Nature',
#  649: 'Social Media',
#  650: 'Tea',
#  651: 'Art and Photography',
#  652: 'Visual Art',
#  653: 'Western Historical Romance',
#  654: 'Burundi',
#  655: 'American Classics',
#  656: 'Zimbabwe',
#  657: 'Semiotics',
#  658: 'Plus Size',
#  659: 'Folk Tales',
#  660: 'Geology',
#  661: 'Banking',
#  662: 'Malawi',
#  663: 'Climate Change',
#  664: 'Romanovs',
#  665: '2nd Grade',
#  666: 'Divination',
#  667: 'Drinking',
#  668: 'Food Writing',
#  669: 'Polyamory',
#  670: 'Pre K',
#  671: 'Climate Change Fiction',
#  672: 'Disease',
#  673: 'Post Colonial',
#  674: 'Harlequin Heartwarming',
#  675: 'Harlequin',
#  676: 'Wine',
#  677: 'Reverse Harem',
#  678: 'Baha I',
#  679: 'Scripture',
#  680: 'Software',
#  681: 'Coding',
#  682: 'Graphic Novels Manga',
#  683: 'Usability',
#  684: 'Website Design',
#  685: 'New Adult Romance',
#  686: 'African American Romance',
#  687: '40k',
#  688: 'Warcraft',
#  689: 'World Of Warcraft',
#  690: 'Togo',
#  691: 'Nerd',
#  692: 'Soviet History',
#  693: 'Russian Revolution',
#  694: 'Victor Frankenstein',
#  695: '1st Grade',
#  696: 'Musicals',
#  697: 'Labor',
#  698: 'Doctor Who',
#  699: 'Belgian',
#  700: 'Feminist Theory',
#  701: 'Mozambique',
#  702: 'School Stories',
#  703: 'Firefighters',
#  704: 'Fire Services',
#  705: 'Emergency Services',
#  706: 'Buses',
#  707: 'Webcomic',
#  708: 'Tv',
#  709: 'New Testament',
#  710: 'Paranormal Urban Fantasy',
#  711: 'Sword and Planet',
#  712: 'Slash Fiction',
#  713: 'Yeti',
#  714: 'Roman Britain',
#  715: 'Category Romance',
#  716: 'Buffy The Vampire Slayer',
#  717: 'Genderqueer',
#  718: 'Amish Fiction',
#  719: 'Asexual',
#  720: 'Komik',
#  721: 'Lenin',
#  722: 'International Development',
#  723: 'International Relations',
#  724: 'Star Trek',
#  725: 'Fractured Fairy Tales',
#  726: 'Edwardian',
#  727: 'Role Playing Games',
#  728: 'Growth Mindset',
#  729: 'Mary Shelley',
#  730: 'Intersex',
#  731: 'Weird West',
#  732: 'Marathi',
#  733: 'Planets',
#  734: 'Witchcraft',
#  735: 'Planetary Romance',
#  736: 'Comedian',
#  737: 'Alcohol',
#  738: 'Bisexual',
#  739: 'Quilting',
#  740: 'Pilots',
#  741: 'Mali',
#  742: 'Spider Man',
#  743: 'Vegetarian',
#  744: 'Cryptozoology',
#  745: 'Trivia',
#  746: 'Victorian Romance',
#  747: 'Harem',
#  748: 'Ethnography',
#  749: 'Eritrea',
#  750: 'Cultural Studies',
#  751: 'International Literature',
#  752: 'Frugal',
#  753: 'Grad School',
#  754: 'Pornography',
#  755: 'Sex Work',
#  756: 'Loveswept',
#  757: 'Doctors',
#  758: 'Alternative Medicine',
#  759: 'Alchemy',
#  760: 'Food History',
#  761: 'Numerology',
#  762: 'Supernatural Romance',
#  763: 'Cocktails',
#  764: 'Booze',
#  765: 'Strippers',
#  766: 'Museums',
#  767: 'Museology',
#  768: 'Agriculture',
#  769: 'Horticulture',
#  770: 'Battle Of Gettysburg',
#  771: 'Fan Fiction',
#  772: 'Evangelism',
#  773: 'Lie',
#  774: 'Golden Age Mystery',
#  775: 'Sewing',
#  776: 'Social Movements',
#  777: 'NSFW',
#  778: 'Ecclesiology',
#  779: 'Astrology',
#  780: 'Students',
#  781: 'Intelligent Design',
#  782: 'Tanzania',
#  783: 'Yaoi',
#  784: 'Boys Love',
#  785: 'Shounen Ai',
#  786: 'Star Trek The Next Generation',
#  787: 'Bizarro Fiction',
#  788: 'Academics',
#  789: 'Gay For You',
#  790: 'Green',
#  791: 'Zambia',
#  792: 'M F M',
#  793: 'Love Inspired Suspense',
#  794: 'Esp',
#  795: 'Namibia',
#  796: 'Bicycles',
#  797: 'Helicopters',
#  798: 'Amateur Sleuth',
#  799: 'Cars',
#  800: 'Apple',
#  801: 'Nazi Party',
#  802: 'Futuristic Romance',
#  803: 'Electrical Engineering',
#  804: 'Conservation',
#  805: 'M M Contemporary',
#  806: 'Goddess',
#  807: 'Cartography',
#  808: 'Harlequin Historical',
#  809: 'Hqn',
#  810: 'Canon',
#  811: 'Interracial Romance',
#  812: 'Motorcycle',
#  813: 'Muslimah',
#  814: 'Geoffrey Chaucer',
#  815: 'Yuri',
#  816: 'Nursing',
#  817: 'Harlequin Romance',
#  818: 'Cryptids',
#  819: 'Traditional Chinese Medicine',
#  820: 'Georgian Romance',
#  821: 'Foster Parents',
#  822: 'Field Guides',
#  823: 'Ornithology',
#  824: 'Multicultural Literature',
#  825: 'Human Development',
#  826: 'Soviet Union',
#  827: 'Figure Skating',
#  828: 'Vaccines',
#  829: 'Egyptology',
#  830: 'Mills and Boon',
#  831: 'Latin American History',
#  832: '11th Century',
#  833: 'Norman',
#  834: 'Harlequin Desire',
#  835: 'Algorithms',
#  836: 'Butch Femme',
#  837: 'Libya',
#  838: 'Northern Africa',
#  839: 'Uganda',
#  840: 'Creation Science',
#  841: 'Erotic Horror',
#  842: 'Naval Historical Fiction',
#  843: 'Harlequin Blaze',
#  844: 'Star Trek Deep Space Nine',
#  845: 'Silhouette',
#  846: 'Choose Your Own Adventure',
#  847: 'Gamebooks',
#  848: 'Gender and Sexuality',
#  849: 'Babylon 5',
#  850: 'Spiritualism',
#  851: 'Fantasy Of Manners',
#  852: '漫画',
#  853: 'Ivory Coast',
#  854: 'Western Africa',
#  855: 'Republic Of The Congo',
#  856: 'Woodwork',
#  857: 'Web',
#  858: 'World Of Darkness',
#  859: 'Cross Dressing',
#  860: 'Fundamentalism',
#  861: 'Central Africa',
#  862: 'Manga Romance',
#  863: 'Railways',
#  864: 'Anti Intellectualism',
#  865: 'Game Design',
#  866: 'Benin',
#  867: 'Taxation',
#  868: 'Beer',
#  869: 'Librarianship',
#  870: 'Vegetarianism',
#  871: 'Harlequin Nocturne',
#  872: 'Pseudoscience',
#  873: 'Viking Romance',
#  874: 'Queer Studies',
#  875: 'Words',
#  876: 'Cultural Heritage',
#  877: 'Maps',
#  878: 'Global Warming',
#  879: 'Whodunit',
#  880: 'Gastronomy',
#  881: 'Back To School',
#  882: 'Japanese History',
#  883: 'Theosophy',
#  884: 'M M Historical Romance',
#  885: 'Tarot',
#  886: 'Jewellery',
#  887: 'Disability Studies',
#  888: 'Erotic Paranormal Romance',
#  889: 'Mira',
#  890: 'Comics Bd',
#  891: 'Herbs',
#  892: 'Eastern Africa',
#  893: 'Christian Contemporary Fiction',
#  894: 'Senegal',
#  895: 'Library Science',
#  896: 'Cuisine',
#  897: 'Battle Of Britain',
#  898: 'History Of Medicine',
#  899: 'Moroccan',
#  900: 'Algebra',
#  901: 'Did Not Finish',
#  902: 'Low Fantasy',
#  903: 'Brewing',
#  904: 'Black Literature',
#  905: 'Gothic Horror',
#  906: 'Homeschool',
#  907: 'Social Change',
#  908: 'Manhwa',
#  909: 'Star Trek Original Series',
#  910: 'Colouring Books',
#  911: 'Aeroplanes',
#  912: 'Go',
#  913: 'Pre Raphaelite',
#  914: 'Graphic Novels Comics Manga',
#  915: 'Goth',
#  916: 'Civil War History',
#  917: 'Mixed Martial Arts',
#  918: 'Stuart',
#  919: 'Wonder Woman',
#  920: 'Information Science',
#  921: 'Star Trek Voyager',
#  922: 'Racing',
#  923: 'Led Zeppelin',
#  924: 'Belief',
#  925: 'Naturopathy',
#  926: 'Earth Sciences',
#  927: 'Classical Music',
#  928: 'Food Preservation',
#  929: 'Atlases',
#  930: '10th Century',
#  931: 'Spanish History',
#  932: 'Motorcycling',
#  933: 'Civil War Eastern Theater',
#  934: 'Traditional Regency',
#  935: 'Ukrainian Literature',
#  936: 'Stand Up',
#  937: 'Human Resources',
#  938: 'Soldiers',
#  939: 'London Underground',
#  940: 'Reportage',
#  941: 'Peak Oil',
#  942: 'Airships',
#  943: 'Guinea'}

# %%
data_clean = data_genres_not_empty.head(1000)
data_clean = data_clean.sample(frac=1).reset_index(drop=True)
data_clean = data_clean.drop("language", axis=1)
data_clean.to_csv('BestBooksEverClean.csv', index=None)

# %%
data_to_train = data_clean.drop("publishDate", axis=1)
data_to_train.to_csv('BestBooksEverClean_train_dataset.csv', index=None)
