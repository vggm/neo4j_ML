# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %%
pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

# %% [markdown]
# ## Load Data

# %%
dataset = pd.read_csv('../datasets/BestBooksEverClean_train_dataset.csv', index_col=None)
dataset
# Out:
#                                                    title          series                author                                             genres  pages  publishYear  rating  likedPercent  price
# 0      Lean Hospitals: Improving Quality, Patient Saf...      standalone           Mark Graban                                     ['Nonfiction']    252         2008    4.01          97.0   4.95
# 1                                   To Have and Have Not      standalone      Ernest Hemingway  ['Fiction', 'Classics', 'Literature', 'Novels'...    176         1999    3.55          87.0   8.49
# 2                          Acacia: The War with the Mein          Acacia  David Anthony Durham  ['Fantasy', 'Fiction', 'Epic Fantasy', 'High F...    576         2007    3.56          85.0   4.36
# 3                                             Dismantled      standalone      Jennifer McMahon  ['Mystery', 'Fiction', 'Thriller', 'Suspense',...    422         2009    3.62          87.0   3.93
# 4                                     The Rabbit Factory      standalone           Larry Brown  ['Fiction', 'Southern', 'Audiobook', 'Contempo...    352         2003    3.57          86.0   6.09
# ...                                                  ...             ...                   ...                                                ...    ...          ...     ...           ...    ...
# 31802                       The Complete Collected Poems      standalone          Maya Angelou  ['Poetry', 'Classics', 'Feminism', 'Nonfiction...    273         1994    4.41          97.0   7.79
# 31803                                 The Same Old Story      standalone        Ivan Goncharov  ['Russia', 'Classics', 'Russian Literature', '...    392         2001    4.18          96.0  36.26
# 31804                                     Love Walked In  Love Walked In  Marisa de los Santos  ['Fiction', 'Chick Lit', 'Romance', 'Contempor...    307         2006    3.72          90.0   0.85
# 31805                                          Geek Love      standalone        Katherine Dunn  ['Fiction', 'Horror', 'Fantasy', 'Contemporary...    348         2002    3.95          90.0   5.38
# 31806                                          Renegades       Renegades         Marissa Meyer  ['Fantasy', 'Young Adult', 'Science Fiction', ...    556         2017    4.15          95.0  12.61
#
# [31807 rows x 9 columns]

# %% [markdown]
# ## Categorize Numeric Cols

# %%
dataset['rating_cat'] = pd.cut(dataset["rating"], bins=[0, 2, 2.5, 3, 4, 4.5, 5], labels=['Muy Malo', 'Malo', 'Mediocre', 'Bueno', 'Muy Bueno', 'Excelente'])
dataset['pages_cat'] = pd.cut(dataset["pages"], bins=[0, 150, 250, 500, 1000, float('Inf')], labels=['Corto', 'Medio', 'Moderado', 'Largo', 'Muy Largo'])
dataset['price_cat'] = pd.cut(dataset["price"], bins=[0, 5, 10, 20, 30, float('Inf')], labels=['Muy Barato', 'Barato', 'Buen Precio', 'Caro', 'Muy Caro'])
dataset['publishDecade'] = (dataset['publishYear'].astype(int) // 10) * 10
# dataset

# %% [markdown]
# ## From String list, return the list of genres

# %%
def genres_to_list(genres: str) -> list:
  list_of_genres = genres.removeprefix('[').removesuffix(']').split(', ')
  return list(map(lambda s: s[1:][:-1], list_of_genres))

# %%
dataset["genres"] = dataset["genres"].apply(genres_to_list)

# %% [markdown]
# ## Make the transactions that would like to compare

# %%
transactions = []
for _, row in dataset.iterrows():
    # transaction = set([row['author']] + row['genres'] + [str(row['publishDecade']), str(row['pages_cat']), str(row['price_cat']), str(row['rating_cat'])])
    # transactions.append(list(transaction))
    transactions.append(row['genres'])
transactions
# Out:
# [['Nonfiction'],
#  ['Fiction',
#   'Classics',
#   'Literature',
#   'Novels',
#   'American',
#   '20th Century',
#   'Literary Fiction',
#   'Classic Literature',
#   'The United States Of America',
#   'Modern Classics'],
#  ['Fantasy',
#   'Fiction',
#   'Epic Fantasy',
#   'High Fantasy',
#   'Science Fiction Fantasy',
#   'Science Fiction',
#   'Epic',
#   'Speculative Fiction',
#   'War',
#   'Audiobook'],
#  ['Mystery',
#   'Fiction',
#   'Thriller',
#   'Suspense',
#   'Mystery Thriller',
#   'Crime',
#   'Adult',
#   'Horror',
#   'Adult Fiction',
#   'Ghosts'],
#  ['Fiction',
#   'Southern',
#   'Audiobook',
#   'Contemporary',
#   'Humor',
#   'Literature',
#   'Dogs',
#   'Southern Gothic'],
#  ['Africa', 'Botswana', 'Mystery', 'Fiction', 'The World', 'Crime'],
#  ['Young Adult',
#   'Science Fiction',
#   'Dystopia',
#   'Fantasy',
#   'Fiction',
#   'Adventure',
#   'Romance',
#   'Action',
#   'Futuristic',
#   'War'],
#  ['Art',
#   'Nonfiction',
#   'Philosophy',
#   'France',
#   'Essays',
#   'Theory',
#   'Poetry',
#   'French Literature',
#   'Art History',
#   'Classics'],
#  ['Fantasy', 'Adventure', 'Fiction', 'Young Adult', 'Humor', 'Comedy'],
#  ['Short Stories',
#   'Fiction',
#   'Literature',
#   'Classics',
#   'Womens',
#   'American',
#   'Short Story Collection',
#   'The United States Of America',
#   'Contemporary',
#   'Anthologies'],
#  ['History',
#   'Nonfiction',
#   'Biography',
#   'World War II',
#   'War',
#   'Holocaust',
#   'Germany',
#   'Psychology',
#   'Politics',
#   'Journalism'],
#  ['Fantasy',
#   'Young Adult',
#   'Romance',
#   'Magic',
#   'Fiction',
#   'Young Adult Fantasy',
#   'Fairies',
#   'Paranormal',
#   'Adventure',
#   'Teen'],
#  ['Historical Romance',
#   'Romance',
#   'Historical',
#   'Regency',
#   'Regency Romance',
#   'Historical Fiction',
#   'Adult',
#   'Fiction',
#   'Military Fiction',
#   'British Literature'],
#  ['Science Fiction',
#   'Video Games',
#   'Gaming',
#   'Fiction',
#   'Fantasy',
#   'Military Fiction',
#   'Space Opera',
#   'Science Fiction Fantasy',
#   'Games',
#   'Space'],
#  ['History', 'Nonfiction', 'Canada', 'Humor', 'Politics'],
#  ['Urban Fantasy',
#   'Fantasy',
#   'Paranormal',
#   'Vampires',
#   'Werewolves',
#   'Romance',
#   'Paranormal Romance',
#   'Shapeshifters',
#   'Magic',
#   'Fiction'],
#  ['Fiction',
#   'Classics',
#   'Jewish',
#   'Literature',
#   'Novels',
#   'American',
#   'Americana',
#   'Literary Fiction',
#   'The United States Of America',
#   'New York'],
#  ['Classics',
#   'Fiction',
#   'Russia',
#   'Russian Literature',
#   'Short Stories',
#   'Literature',
#   'Novels',
#   'Romance',
#   '19th Century',
#   'Classic Literature'],
#  ['Nonfiction',
#   'Memoir',
#   'Writing',
#   'Education',
#   'Teaching',
#   'Adult',
#   'Biography',
#   'Biography Memoir',
#   'Sociology',
#   'Books About Books'],
#  ['Fantasy',
#   'Fiction',
#   'Short Stories',
#   'Young Adult',
#   'Science Fiction',
#   'Science Fiction Fantasy',
#   'Magic',
#   'High Fantasy',
#   'Dragons',
#   'Classics'],
#  ['Graphic Novels',
#   'Young Adult',
#   'Dystopia',
#   'Comics',
#   'Science Fiction',
#   'Romance',
#   'Fiction',
#   'Graphic Novels Comics',
#   'Manga',
#   'Fantasy'],
#  ['History',
#   'Nonfiction',
#   'Military Fiction',
#   'American History',
#   'Military History',
#   'Historical',
#   'Audiobook',
#   'War',
#   'Unfinished',
#   'Politics'],
#  ['Childrens',
#   'Picture Books',
#   'Fiction',
#   'Animals',
#   'Fantasy',
#   'Dogs',
#   'Classics',
#   'Juvenile'],
#  ['Chick Lit',
#   'Fiction',
#   'Romance',
#   'Contemporary',
#   'Novels',
#   'Contemporary Romance',
#   'Audiobook',
#   'Womens Fiction',
#   'Relationships'],
#  ['Fantasy',
#   'Middle Grade',
#   'Childrens',
#   'Fiction',
#   'Juvenile',
#   'Mystery',
#   'Australia',
#   'Magic',
#   'Family',
#   'Audiobook'],
#  ['Middle Grade',
#   'Sports',
#   'Realistic Fiction',
#   'Young Adult',
#   'Fiction',
#   'Audiobook',
#   'Contemporary',
#   'Family',
#   'Juvenile',
#   'Childrens'],
#  ['Historical Fiction',
#   'Historical',
#   'Medieval',
#   'Fiction',
#   'British Literature',
#   'Romance',
#   'Historical Romance',
#   '12th Century',
#   'Plantagenet',
#   '13th Century'],
#  ['Picture Books',
#   'Childrens',
#   'Humor',
#   'Fiction',
#   'Animals',
#   'Storytime',
#   'Juvenile',
#   'Kids',
#   'School',
#   'Young Adult'],
#  ['Business',
#   'Nonfiction',
#   'Biography',
#   'Leadership',
#   'History',
#   'Management',
#   'Buisness',
#   'Economics',
#   'Audiobook',
#   'Finance'],
#  ['Fiction',
#   'Literary Fiction',
#   'Contemporary',
#   'Environment',
#   'Adult Fiction',
#   'Book Club',
#   'Novels',
#   'Climate Change',
#   'Audiobook',
#   'Nature'],
#  ['Fiction', 'LGBT', 'Lesbian', 'Lesbian Fiction', 'Queer', 'Novels'],
#  ['Contemporary Romance',
#   'Romance',
#   'Contemporary',
#   'Adult',
#   'Erotica',
#   'Chick Lit',
#   'Abuse',
#   'M F Romance',
#   'Prostitution',
#   'Drama'],
#  ['Historical Fiction', 'Fiction', 'Mystery', 'True Crime'],
#  ['Fiction',
#   'Historical Fiction',
#   'Canada',
#   'Adult Fiction',
#   'Book Club',
#   'Contemporary',
#   'Novels',
#   'Historical',
#   'Adult',
#   'Chick Lit'],
#  ['Fiction',
#   'Religion',
#   'Historical',
#   'Thriller',
#   'Mystery',
#   'Historical Fiction',
#   'Adventure',
#   'Literature',
#   'Biblical Fiction',
#   'Academia'],
#  ['Fantasy',
#   'Young Adult',
#   'Romance',
#   'Magic',
#   'Fiction',
#   'Fairies',
#   'Young Adult Fantasy',
#   'Paranormal',
#   'Fae',
#   'Teen'],
#  ['Fantasy',
#   'Fiction',
#   'Epic Fantasy',
#   'Science Fiction Fantasy',
#   'High Fantasy',
#   'Science Fiction',
#   'Magic',
#   'Adventure',
#   'Epic',
#   'Novels'],
#  ['Comics',
#   'Graphic Novels',
#   'Dc Comics',
#   'Superheroes',
#   'Graphic Novels Comics',
#   'Comic Book',
#   'Fiction',
#   'Adventure',
#   'Comics Manga',
#   'Action'],
#  ['German Literature', 'Germany', 'Fiction', 'Childrens'],
#  ['Poetry',
#   'Classics',
#   'Plays',
#   'Drama',
#   'Gothic',
#   'Romanticism',
#   'Fiction',
#   'Fantasy',
#   '19th Century',
#   'British Literature'],
#  ['Sports',
#   'Fitness',
#   'Nonfiction',
#   'Health',
#   'Reference',
#   'Outdoors',
#   'Self Help',
#   'Science'],
#  ['Fiction',
#   'Noir',
#   'Mystery',
#   'Crime',
#   'Novels',
#   'Classics',
#   'Thriller',
#   'American',
#   'New York',
#   'Literature'],
#  ['Historical Fiction',
#   'Christian Fiction',
#   'Romance',
#   'Christian',
#   'Fiction',
#   'Historical',
#   'Historical Romance',
#   'Christian Romance',
#   'Inspirational',
#   'Amish'],
#  ['Fiction'],
#  ['Fiction',
#   'Historical Fiction',
#   'African American',
#   'Literary Fiction',
#   'War',
#   'Literature',
#   'Novels',
#   'Audiobook',
#   'Adult Fiction',
#   'Contemporary'],
#  ['Young Adult',
#   'Romance',
#   'Contemporary',
#   'Fiction',
#   'Realistic Fiction',
#   'Young Adult Contemporary',
#   'Audiobook',
#   'High School',
#   'Teen',
#   'Young Adult Romance'],
#  ['Vampires',
#   'Young Adult',
#   'Paranormal',
#   'Romance',
#   'Fantasy',
#   'Paranormal Romance',
#   'Fiction',
#   'Teen',
#   'Supernatural',
#   'Urban Fantasy'],
#  ['Horror',
#   'Fiction',
#   'Classics',
#   'Paranormal',
#   'Thriller',
#   'Fantasy',
#   'Supernatural',
#   'Mystery',
#   'Suspense',
#   'Adult'],
#  ['Historical Fiction',
#   'Historical',
#   'Young Adult',
#   'Fiction',
#   'Childrens',
#   'Middle Grade',
#   'Diary',
#   'Juvenile',
#   '19th Century',
#   'American'],
#  ['Self Help', 'Nonfiction', 'Leadership', 'Business', 'Inspirational'],
#  ['Steampunk',
#   'Fantasy',
#   'Paranormal',
#   'Romance',
#   'Fiction',
#   'Vampires',
#   'Young Adult',
#   'Historical Fiction',
#   'Adventure',
#   'Werewolves'],
#  ['Mystery',
#   'Suspense',
#   'Fiction',
#   'Thriller',
#   'Romance',
#   'Mystery Thriller',
#   'Crime',
#   'Romantic Suspense',
#   'Contemporary',
#   'Audiobook'],
#  ['Historical Fiction',
#   'Fiction',
#   'Middle Grade',
#   'Childrens',
#   'School',
#   'Sports',
#   'Young Adult',
#   'Teaching',
#   'Chapter Books',
#   'Juvenile'],
#  ['Mystery',
#   'Fiction',
#   'Art',
#   'Crime',
#   'Italy',
#   'Mystery Thriller',
#   'Detective',
#   'British Literature',
#   'Thriller',
#   'Art History'],
#  ['Fiction',
#   'New York',
#   'Contemporary',
#   'Coming Of Age',
#   'The United States Of America',
#   'Novels',
#   'American',
#   'New Adult',
#   'Jewish',
#   'Chick Lit'],
#  ['Historical Fiction',
#   'Fiction',
#   'Historical',
#   'Literature',
#   'War',
#   'Fantasy',
#   'Novels',
#   'Ancient',
#   'Ancient History',
#   'Historical Romance'],
#  ['Picture Books',
#   'Childrens',
#   'Animals',
#   'Family',
#   'Fiction',
#   'Fantasy',
#   'School',
#   'Kids',
#   'Emotion',
#   'Humor'],
#  ['Young Adult',
#   'Realistic Fiction',
#   'Fiction',
#   'Mystery',
#   'Teen',
#   'Suspense',
#   'School',
#   'Thriller',
#   'Contemporary',
#   'High School'],
#  ['Horror',
#   'Fiction',
#   'Classics',
#   'Thriller',
#   'Mystery',
#   'Fantasy',
#   'Paranormal',
#   'Supernatural',
#   'Suspense',
#   'Adult'],
#  ['Fiction',
#   'France',
#   'Classics',
#   'French Literature',
#   'Literature',
#   'Novels',
#   'Womens',
#   'Female Authors',
#   '20th Century',
#   'Literary Fiction'],
#  ['Romance',
#   'Dark',
#   'Erotica',
#   'Adult',
#   'BDSM',
#   'Suspense',
#   'Contemporary',
#   'Abuse',
#   'New Adult',
#   'Crime'],
#  ['Historical Fiction',
#   'Fiction',
#   'Historical',
#   'Medieval',
#   'British Literature',
#   '15th Century',
#   'Plantagenet',
#   'Romance',
#   'Novels',
#   'War'],
#  ['Fantasy',
#   'Young Adult',
#   'Fairies',
#   'Fiction',
#   'Magic',
#   'Urban Fantasy',
#   'Adventure',
#   'Fae',
#   'Teen',
#   'Young Adult Fantasy'],
#  ['Fiction',
#   'Classics',
#   'Southern Gothic',
#   'Literature',
#   'Novels',
#   'Gothic',
#   'Southern',
#   'American',
#   'Literary Fiction',
#   'Religion'],
#  ['Fiction',
#   'Romance',
#   'Chick Lit',
#   'Contemporary',
#   'Adult Fiction',
#   'Novels',
#   'Womens Fiction',
#   'Adult',
#   'Drama',
#   'Literary Fiction'],
#  ['Fantasy',
#   'Fiction',
#   'Young Adult',
#   'Science Fiction Fantasy',
#   'Classics',
#   'High Fantasy',
#   'Science Fiction',
#   'Magic',
#   'Adventure',
#   'Dragons'],
#  ['Middle Grade',
#   'Realistic Fiction',
#   'Childrens',
#   'Young Adult',
#   'Contemporary',
#   'Chick Lit',
#   'Humor',
#   'Fiction',
#   'Juvenile',
#   'Chapter Books'],
#  ['Historical Fiction',
#   'Fiction',
#   'War',
#   'World War I',
#   'Historical',
#   'British Literature',
#   '20th Century',
#   'Literary Fiction',
#   'Literature',
#   'Novels'],
#  ['Classics',
#   'Fiction',
#   'Literature',
#   'Adventure',
#   'Novels',
#   'Historical Fiction',
#   'British Literature',
#   'Classic Literature',
#   'Literary Fiction',
#   '20th Century'],
#  ['Romance',
#   'Contemporary Romance',
#   'Contemporary',
#   'Westerns',
#   'Fiction',
#   'Historical Romance',
#   'Harlequin',
#   'Historical',
#   'M F Romance',
#   'Chick Lit'],
#  ['Fiction',
#   'Classics',
#   'Humor',
#   'British Literature',
#   'Historical Fiction',
#   'Comedy',
#   '20th Century',
#   'Novels',
#   'Literature',
#   'Historical'],
#  ['Memoir',
#   'Nonfiction',
#   'Nature',
#   'Environment',
#   'Biography Memoir',
#   'Biography',
#   'History',
#   'Natural History',
#   'Science',
#   'Essays'],
#  ['Fantasy',
#   'Fiction',
#   'Classics',
#   'Christian',
#   'Fairy Tales',
#   'Literature',
#   'Christian Fiction',
#   'Science Fiction Fantasy',
#   '19th Century',
#   'Christianity'],
#  ['Theology',
#   'Christian',
#   'Nonfiction',
#   'Religion',
#   'Christianity',
#   'Faith',
#   'Spirituality',
#   'Christian Living',
#   'Church',
#   'Christian Non Fiction'],
#  ['Historical Fiction',
#   'Fiction',
#   'Fantasy',
#   'Historical',
#   'Adventure',
#   'Egypt',
#   'Thriller',
#   'Mystery',
#   'Africa',
#   'Novels'],
#  ['Romance',
#   'Contemporary Romance',
#   'Contemporary',
#   'Fiction',
#   'Family',
#   'Chick Lit',
#   'Adult',
#   'Marriage',
#   'Humor',
#   'Drama'],
#  ['Fiction',
#   'Religion',
#   'Contemporary',
#   'Adult Fiction',
#   'Literary Fiction',
#   'Coming Of Age',
#   'American',
#   'Adult',
#   'Literature',
#   'The United States Of America'],
#  ['Fiction',
#   'Mystery',
#   'Historical Fiction',
#   'Thriller',
#   'Audiobook',
#   'Crime',
#   'Legal Thriller',
#   'Mystery Thriller',
#   'Suspense',
#   'Novels'],
#  ['Science',
#   'Nonfiction',
#   'Biology',
#   'Evolution',
#   'Philosophy',
#   'Psychology',
#   'Popular Science',
#   'Genetics',
#   'Audiobook',
#   'Atheism'],
#  ['Poetry',
#   'Contemporary',
#   'Fiction',
#   'American',
#   'Adult',
#   'Humor',
#   'School',
#   'Literary Fiction',
#   'Literature',
#   'Read For School'],
#  ['Fantasy', 'Science Fiction', 'Young Adult'],
#  ['Philosophy',
#   'Politics',
#   'Nonfiction',
#   'Theory',
#   'History',
#   'Sociology',
#   'Academic',
#   'Economics',
#   'Essays',
#   'Italian Literature'],
#  ['Fiction',
#   'Historical Fiction',
#   'Westerns',
#   'Historical',
#   'Novels',
#   'Indian Literature',
#   'Literature',
#   'Native Americans',
#   'Adventure',
#   'The United States Of America'],
#  ['Fiction',
#   'Christian Fiction',
#   'Christian',
#   'Spirituality',
#   'Religion',
#   'Inspirational',
#   'Faith',
#   'Contemporary',
#   'Adult',
#   'Novels'],
#  ['Chick Lit',
#   'Fiction',
#   'Romance',
#   'British Literature',
#   'Novels',
#   'Drama',
#   'Historical Fiction',
#   'Contemporary'],
#  ['Comics',
#   'Graphic Novels',
#   'Science Fiction',
#   'Alternate History',
#   'Fiction',
#   'Graphic Novels Comics',
#   'Comic Book',
#   'Fantasy',
#   'Alternate Universe',
#   'War'],
#  ['Fiction',
#   'Literary Fiction',
#   'Historical Fiction',
#   'Denmark',
#   'Novels',
#   'Literature',
#   'Psychology'],
#  ['Fantasy',
#   'Young Adult',
#   'Magic',
#   'Paranormal',
#   'Fiction',
#   'Amazon',
#   'Mystery',
#   'Urban Fantasy',
#   'Adventure',
#   'Science Fiction Fantasy'],
#  ['Star Trek',
#   'Science Fiction',
#   'Fiction',
#   'Science Fiction Fantasy',
#   'Media Tie In',
#   'Audiobook',
#   'Star Trek The Next Generation',
#   'Tv',
#   'Space',
#   'Novels'],
#  ['Fantasy',
#   'Fiction',
#   'New Weird',
#   'Speculative Fiction',
#   'High Fantasy',
#   'Novels',
#   'Science Fiction',
#   'Science Fiction Fantasy',
#   'Epic Fantasy'],
#  ['Comics',
#   'Humor',
#   'Graphic Novels',
#   'Fiction',
#   'Comic Book',
#   'Comedy',
#   'Comic Strips',
#   'Graphic Novels Comics',
#   'Childrens',
#   'Cartoon'],
#  ['Classics',
#   'Fiction',
#   'Romance',
#   'Novels',
#   '20th Century',
#   'British Literature',
#   'Literature',
#   'Feminism',
#   'English Literature',
#   'Womens'],
#  ['Paranormal Romance',
#   'Paranormal',
#   'Romance',
#   'Witches',
#   'Magic',
#   'Urban Fantasy',
#   'Fantasy',
#   'Adult',
#   'Fiction',
#   'Erotica'],
#  ['Historical Fiction',
#   'Fiction',
#   'Classics',
#   'Young Adult',
#   'Childrens',
#   'Historical',
#   'School',
#   'Adventure',
#   'Middle Grade',
#   'Juvenile'],
#  ['Paranormal',
#   'Paranormal Romance',
#   'Romance',
#   'Fantasy',
#   'Urban Fantasy',
#   'Erotica',
#   'Demons',
#   'Fiction',
#   'Reverse Harem',
#   'Vampires'],
#  ['Programming',
#   'Computer Science',
#   'Nonfiction',
#   'Reference',
#   'Technology',
#   'Technical',
#   'Computers',
#   'Software',
#   'Textbooks',
#   'Science'],
#  ['Classics',
#   'Plays',
#   'Drama',
#   'Fiction',
#   'School',
#   'Romance',
#   'Theatre',
#   'Literature',
#   'Poetry',
#   'Read For School'],
#  ['Historical Fiction',
#   'Fiction',
#   'LGBT',
#   'Historical',
#   'Gothic',
#   'Mystery',
#   'Queer',
#   'Lesbian',
#   'Romance',
#   'Victorian'],
#  ['Young Adult',
#   'Fantasy',
#   'Paranormal',
#   'Romance',
#   'Fiction',
#   'Urban Fantasy',
#   'Supernatural',
#   'Paranormal Romance',
#   'Mythology',
#   'Young Adult Fantasy'],
#  ['Romance',
#   'Mystery',
#   'Romantic',
#   'Love Story',
#   'Fiction',
#   'Thriller',
#   'New Adult',
#   'Adventure',
#   '21st Century',
#   'Modern'],
#  ['Historical Fiction',
#   'Fiction',
#   'Historical',
#   'Fantasy',
#   'Witches',
#   'Medieval',
#   'Paranormal',
#   'France',
#   'Historical Fantasy',
#   'Romance'],
#  ['Sports', 'Fiction', 'Football', 'Humor', 'Novels', 'American'],
#  ['Fiction',
#   'Contemporary',
#   'Literary Fiction',
#   'Novels',
#   'Literature',
#   'Adult Fiction',
#   'Book Club',
#   'Adult',
#   'American',
#   'Audiobook'],
#  ['Fiction',
#   'Classics',
#   'Historical Fiction',
#   'Romance',
#   'Magical Realism',
#   'Literature',
#   'Novels',
#   'Spanish Literature',
#   'Literary Fiction',
#   'Historical'],
#  ['Fiction',
#   'Chick Lit',
#   'Southern',
#   'Humor',
#   'Adult Fiction',
#   'Historical Fiction',
#   'Contemporary',
#   'Adult',
#   'Novels',
#   'Womens Fiction'],
#  ['Historical Fiction',
#   'Fiction',
#   'Historical',
#   'Italy',
#   'Audiobook',
#   'Adult',
#   '16th Century',
#   'Religion',
#   'Adult Fiction',
#   'Cultural'],
#  ['Business',
#   'Nonfiction',
#   'Self Help',
#   'Leadership',
#   'Personal Development',
#   'Reference',
#   'Psychology',
#   'Management',
#   'Buisness',
#   'Productivity'],
#  ['Science',
#   'Nonfiction',
#   'Biology',
#   'Nature',
#   'Natural History',
#   'Animals',
#   'Evolution',
#   'Business',
#   'Science Nature',
#   'Environment'],
#  ['Horror',
#   'Fiction',
#   'Thriller',
#   'Fantasy',
#   'Supernatural',
#   'Mystery',
#   'Audiobook',
#   'Suspense',
#   'Paranormal',
#   'Novels'],
#  ['Young Adult',
#   'Romance',
#   'Contemporary',
#   'New Adult',
#   'Chick Lit',
#   'College',
#   'Fiction',
#   'Young Adult Romance',
#   'Realistic Fiction',
#   'Contemporary Romance'],
#  ['Feminism',
#   'Nonfiction',
#   'Plays',
#   'Womens',
#   'Drama',
#   'Gender Studies',
#   'Essays',
#   'Memoir',
#   'Womens Studies',
#   'Theatre'],
#  ['Fiction',
#   'Baseball',
#   'Sports',
#   'Humor',
#   'Audiobook',
#   'Adult Fiction',
#   'Contemporary',
#   'Historical Fiction',
#   'Literature',
#   'Novels'],
#  ['Urban Fantasy',
#   'Vampires',
#   'Paranormal Romance',
#   'Fantasy',
#   'Paranormal',
#   'Romance',
#   'Angels',
#   'Fiction',
#   'Adult',
#   'Demons'],
#  ['Christian Fiction',
#   'Mystery',
#   'Christian',
#   'Fiction',
#   'Suspense',
#   'Mystery Thriller',
#   'Inspirational',
#   'Crime'],
#  ['Fiction',
#   'Thriller',
#   'Mystery',
#   'Suspense',
#   'Mystery Thriller',
#   'Romance',
#   'Novels',
#   'Crime',
#   'Contemporary',
#   'Drama'],
#  ['Fiction',
#   'Historical Fiction',
#   'Literature',
#   'Classics',
#   'Novels',
#   'American',
#   'Literary Fiction',
#   '20th Century',
#   'The United States Of America',
#   'Historical'],
#  ['Fantasy',
#   'Young Adult',
#   'Fiction',
#   'Dragons',
#   'Magic',
#   'Adventure',
#   'High Fantasy',
#   'Epic Fantasy',
#   'Science Fiction Fantasy',
#   'Young Adult Fantasy'],
#  ['Romantic Suspense',
#   'Romance',
#   'Contemporary Romance',
#   'Suspense',
#   'Contemporary',
#   'Adult',
#   'Mystery',
#   'Action',
#   'Erotica',
#   'Mystery Thriller'],
#  ['Comics',
#   'Graphic Novels',
#   'Batman',
#   'Dc Comics',
#   'Comic Book',
#   'Superheroes',
#   'Graphic Novels Comics',
#   'Fiction',
#   'Fantasy',
#   'Comics Manga'],
#  ['Nonfiction',
#   'Feminism',
#   'Science',
#   'Psychology',
#   'Gender',
#   'Sociology',
#   'Gender Studies',
#   'Neuroscience',
#   'Womens',
#   'Politics'],
#  ['Nonfiction'],
#  ['Young Adult',
#   'Contemporary',
#   'Romance',
#   'Fiction',
#   'Realistic Fiction',
#   'Teen',
#   'Abuse',
#   'High School',
#   'Young Adult Contemporary',
#   'Chick Lit'],
#  ['Spirituality',
#   'Nonfiction',
#   'Religion',
#   'Philosophy',
#   'Self Help',
#   'New Age',
#   'Inspirational',
#   'Personal Development',
#   'Metaphysics',
#   'God'],
#  ['Angels',
#   'Young Adult',
#   'Fantasy',
#   'Paranormal',
#   'Romance',
#   'Paranormal Romance',
#   'Urban Fantasy',
#   'Supernatural',
#   'Christian',
#   'Fiction'],
#  ['Fiction',
#   'Hungary',
#   'Historical Fiction',
#   'Hungarian Literature',
#   'Literary Fiction',
#   'Novels',
#   'Literature',
#   'Contemporary',
#   'Historical',
#   '21st Century'],
#  ['Mythology',
#   'Fantasy',
#   'Middle Grade',
#   'Childrens',
#   'Fiction',
#   'Greek Mythology',
#   'Young Adult',
#   'Retellings',
#   'Romance',
#   'Juvenile'],
#  ['Science Fiction',
#   'Fiction',
#   'Short Stories',
#   'Science Fiction Fantasy',
#   'Collections',
#   'Fantasy',
#   'Speculative Fiction',
#   'Classics',
#   'Adventure',
#   'Anthologies'],
#  ['Spirituality'],
#  ['Travel',
#   'History',
#   'Nonfiction',
#   'Biography',
#   'Adventure',
#   'Memoir',
#   'Australia',
#   'Travelogue',
#   'World History',
#   'Historical'],
#  ['Christian Fiction',
#   'Historical Fiction',
#   'Biblical Fiction',
#   'Christian',
#   'Fiction',
#   'Historical',
#   'Romance',
#   'Biblical',
#   'Historical Romance',
#   'Christian Historical Fiction'],
#  ['Fantasy',
#   'Fiction',
#   'Young Adult',
#   'Middle Grade',
#   'Fairy Tales',
#   'Childrens',
#   'Historical Fiction',
#   'Animals',
#   'Juvenile',
#   'Jewish'],
#  ['Nonfiction',
#   'Business',
#   'Psychology',
#   'Economics',
#   'Sociology',
#   'Science',
#   'Politics',
#   'Social Science',
#   'Philosophy',
#   'Leadership'],
#  ['Manga',
#   'Graphic Novels',
#   'Young Adult',
#   'Fantasy',
#   'Science Fiction',
#   'Comics',
#   'Adventure',
#   'Fiction',
#   'Romance',
#   'Action'],
#  ['Fiction',
#   'Childrens',
#   'Young Adult',
#   'Historical Fiction',
#   'Middle Grade',
#   'Humor',
#   'Classics',
#   'New York',
#   'Juvenile',
#   'Chapter Books'],
#  ['Fantasy',
#   'Young Adult',
#   'Magic',
#   'Fiction',
#   'Young Adult Fantasy',
#   'High Fantasy',
#   'Adventure',
#   'Childrens',
#   'Medieval',
#   'Teen'],
#  ['Christian',
#   'Classics',
#   'Christian Fiction',
#   'Fiction',
#   'Childrens',
#   'Religion',
#   'Theology',
#   'Fantasy',
#   'Faith',
#   'Adventure'],
#  ['Poetry',
#   'Classics',
#   'Fiction',
#   '19th Century',
#   'Victorian',
#   'School',
#   'Romance',
#   'British Literature'],
#  ['India', 'Fiction', 'Indian Literature'],
#  ['Mystery',
#   'Fiction',
#   'Thriller',
#   'Mystery Thriller',
#   'Crime',
#   'Suspense',
#   'Audiobook',
#   'Adult',
#   'Contemporary',
#   'Adult Fiction'],
#  ['Fiction',
#   'Classics',
#   'American',
#   'Novels',
#   'Business',
#   'Literature',
#   'Finance',
#   'The United States Of America',
#   '20th Century',
#   'Philosophy'],
#  ['Mystery',
#   'Thriller',
#   'Legal Thriller',
#   'Fiction',
#   'Suspense',
#   'Amazon',
#   'Mystery Thriller',
#   'Crime',
#   'Drama'],
#  ['Urban Fantasy',
#   'Fantasy',
#   'Demons',
#   'Paranormal',
#   'Romance',
#   'Paranormal Romance',
#   'Mystery',
#   'Magic',
#   'Fiction',
#   'Adult'],
#  ['Fantasy',
#   'Urban Fantasy',
#   'Fiction',
#   'Mystery',
#   'Paranormal',
#   'Magic',
#   'Audiobook',
#   'Supernatural',
#   'Vampires',
#   'Science Fiction Fantasy'],
#  ['Poetry', 'Feminism', 'Politics', 'Womens'],
#  ['Physics',
#   'Science',
#   'Nonfiction',
#   'Popular Science',
#   'Philosophy',
#   'Mathematics',
#   'Biography',
#   'Essays',
#   'Nobel Prize',
#   '20th Century'],
#  ['Classics',
#   'German Literature',
#   'Fiction',
#   'Germany',
#   'Literature',
#   'Short Stories',
#   'School',
#   'Novella',
#   'Novels',
#   '20th Century'],
#  ['Young Adult',
#   'Vampires',
#   'Horror',
#   'Fantasy',
#   'Paranormal',
#   'Fiction',
#   'Supernatural',
#   'Urban Fantasy',
#   'Teen',
#   'Romance'],
#  ['Historical Romance',
#   'Romance',
#   'Historical',
#   'Historical Fiction',
#   'Regency',
#   'Adult',
#   'Fiction',
#   'Regency Romance',
#   'Victorian',
#   'Humor'],
#  ['Erotica',
#   'Romance',
#   'BDSM',
#   'Erotic Romance',
#   'Contemporary',
#   'Contemporary Romance',
#   'Adult',
#   'Fiction',
#   'Menage',
#   'Chick Lit'],
#  ['Young Adult',
#   'Contemporary',
#   'Romance',
#   'Teen',
#   'Fiction',
#   'Coming Of Age',
#   'Family',
#   'Fantasy',
#   'Realistic Fiction',
#   'Mystery'],
#  ['Business',
#   'Leadership',
#   'Nonfiction',
#   'Management',
#   'Politics',
#   'Economics',
#   'Audiobook',
#   'Cultural',
#   'Psychology',
#   'Sociology'],
#  ['Fiction',
#   'Ireland',
#   'Chick Lit',
#   'Romance',
#   'Irish Literature',
#   'Historical Fiction',
#   'Contemporary',
#   'Drama',
#   'Adult Fiction',
#   'Womens Fiction'],
#  ['Science Fiction',
#   'Fantasy',
#   'Fiction',
#   'Science Fiction Fantasy',
#   'Speculative Fiction',
#   'Adventure',
#   'Adult',
#   'Aliens',
#   'Criticism',
#   'Classics'],
#  ['Buddhism',
#   'Zen',
#   'Philosophy',
#   'Nonfiction',
#   'Religion',
#   'Spirituality',
#   'Self Help',
#   'Eastern Philosophy',
#   'Japan',
#   'Psychology'],
#  ['Childrens',
#   'Picture Books',
#   'Fiction',
#   'Banned Books',
#   'Classics',
#   'Art',
#   'Humor',
#   'Comics',
#   'Juvenile',
#   'Young Adult'],
#  ['Christian', 'Religion', 'Christian Fiction', 'Spirituality', 'Fiction'],
#  ['Metaphysics', 'Aliens', 'Spirituality'],
#  ['Science',
#   'Physics',
#   'Nonfiction',
#   'Classics',
#   'Philosophy',
#   'Mathematics',
#   'Popular Science',
#   'History',
#   'Reference',
#   '20th Century'],
#  ['Horror',
#   'Vampires',
#   'Fantasy',
#   'Fiction',
#   'Paranormal',
#   'Science Fiction',
#   'Thriller',
#   'Urban Fantasy',
#   'Supernatural',
#   'Novels'],
#  ['Fiction',
#   'Dutch Literature',
#   'Historical Fiction',
#   'Classics',
#   'Literature',
#   'School',
#   'War',
#   'Novels',
#   'World War II',
#   'Read For School'],
#  ['Fiction'],
#  ['Poetry',
#   'Picture Books',
#   'Childrens',
#   'Nonfiction',
#   'Middle Grade',
#   'Humor',
#   'Juvenile',
#   'Realistic Fiction',
#   'School',
#   'Contemporary'],
#  ['Manga',
#   'Vampires',
#   'Romance',
#   'Fantasy',
#   'Graphic Novels',
#   'Young Adult',
#   'Paranormal',
#   'Supernatural',
#   'Shojo',
#   'Anime'],
#  ['Nonfiction',
#   'Africa',
#   'Memoir',
#   'Biography',
#   'Science',
#   'Biography Memoir',
#   'Malawi',
#   'Autobiography',
#   'Inspirational',
#   'School'],
#  ['Mystery',
#   'Adventure',
#   'Young Adult',
#   'Fiction',
#   'Middle Grade',
#   'Childrens',
#   'Fantasy',
#   'Audiobook',
#   'Juvenile',
#   'Action'],
#  ['Law', 'Politics', 'Nonfiction'],
#  ['Young Adult',
#   'Romance',
#   'Fantasy',
#   'Mystery',
#   'Science Fiction',
#   'Paranormal',
#   'Aliens',
#   'Supernatural',
#   'Mystery Thriller'],
#  ['Fiction',
#   'Contemporary',
#   'Novels',
#   'Literary Fiction',
#   'Audiobook',
#   'The United States Of America',
#   'American',
#   'Literature',
#   'Womens',
#   'Family'],
#  ['Fantasy',
#   'Dragons',
#   'Young Adult',
#   'Urban Fantasy',
#   'Fiction',
#   'Paranormal',
#   'Teen',
#   'Adventure',
#   'Romance',
#   'Magic'],
#  ['Young Adult',
#   'Contemporary',
#   'Chick Lit',
#   'Realistic Fiction',
#   'Fiction',
#   'Teen',
#   'Drama',
#   'High School',
#   'Middle Grade'],
#  ['Politics', 'Nonfiction', 'Biography Memoir'],
#  ['Fantasy',
#   'Mermaids',
#   'Childrens',
#   'Middle Grade',
#   'Juvenile',
#   'Chapter Books',
#   'Young Adult'],
#  ['Fantasy',
#   'Childrens',
#   'Fairies',
#   'Fiction',
#   'Sports',
#   'Magic',
#   'Chapter Books',
#   'Adventure'],
#  ['Young Adult',
#   'Romance',
#   'Christmas',
#   'Fiction',
#   'Teen',
#   'Realistic Fiction',
#   'Holiday',
#   'Contemporary',
#   'Chick Lit',
#   'Humor'],
#  ['Historical Fiction',
#   'Young Adult',
#   'Fiction',
#   'Classics',
#   'Romance',
#   'World War II',
#   'Historical',
#   'War',
#   'Childrens',
#   'Holocaust'],
#  ['Writing',
#   'Nonfiction',
#   'Film',
#   'Reference',
#   'Media Tie In',
#   'Art',
#   'Crafts',
#   'How To',
#   'Research',
#   'Textbooks'],
#  ['Fantasy',
#   'Historical Fiction',
#   'Fiction',
#   'Historical Fantasy',
#   'Historical',
#   'Epic Fantasy',
#   'Heroic Fantasy',
#   'Mythology',
#   'Greece',
#   'Science Fiction Fantasy'],
#  ['Fiction', 'Coming Of Age', 'Novels', 'American'],
#  ['Fiction',
#   'Humor',
#   'Novels',
#   'Literature',
#   'Contemporary',
#   'Comedy',
#   'American',
#   'Modern',
#   'Literary Fiction',
#   'Magical Realism'],
#  ['Nonfiction',
#   'Food',
#   'Science',
#   'Health',
#   'History',
#   'Nutrition',
#   'Environment',
#   'Cooking',
#   'Audiobook',
#   'Politics'],
#  ['Fiction',
#   'Mystery',
#   'Thriller',
#   'Historical Fiction',
#   'Books About Books',
#   'Spain',
#   'Mystery Thriller',
#   'Spanish Literature',
#   'Adventure',
#   'Fantasy'],
#  ['Thriller',
#   'Fiction',
#   'Mystery',
#   'Espionage',
#   'Mystery Thriller',
#   'Suspense',
#   'Spy Thriller',
#   'Crime',
#   'Action',
#   'Adventure'],
#  ['Romance',
#   'Chick Lit',
#   'Contemporary Romance',
#   'Fiction',
#   'Contemporary',
#   'Humor',
#   'Mystery',
#   'Adult',
#   'Adult Fiction',
#   'Comedy'],
#  ['Picture Books',
#   'Childrens',
#   'School',
#   'Fiction',
#   'Animals',
#   'Fantasy',
#   'Humor',
#   'Family',
#   'Teachers',
#   'Kids'],
#  ['Fiction',
#   'Historical Fiction',
#   'Russia',
#   'Literature',
#   'Novels',
#   'South Africa',
#   'Nobel Prize',
#   'Africa',
#   'African Literature',
#   '20th Century'],
#  ['Historical Fiction',
#   'Young Adult',
#   'Fiction',
#   'Historical',
#   'School',
#   'Young Adult Historical Fiction',
#   'Middle Grade',
#   'Classics',
#   'Childrens',
#   'American History'],
#  ['Steampunk',
#   'Science Fiction',
#   'Fantasy',
#   'Alternate History',
#   'Time Travel',
#   'Historical Fiction',
#   'Fiction',
#   'Mystery',
#   'Victorian',
#   'Adventure'],
#  ['Urban Fantasy',
#   'Paranormal',
#   'Anthologies',
#   'Fantasy',
#   'Paranormal Romance',
#   'Romance',
#   'Vampires',
#   'Short Stories',
#   'Magic',
#   'Angels'],
#  ['Romance',
#   'Contemporary Romance',
#   'Sports',
#   'Contemporary',
#   'Audiobook',
#   'Sports Romance',
#   'Adult',
#   'Chick Lit',
#   'New Adult',
#   'Erotica'],
#  ['Horror',
#   'Fiction',
#   'Thriller',
#   'Mystery',
#   'Suspense',
#   'Ghosts',
#   'Supernatural',
#   'Adult',
#   'Fantasy',
#   'Mystery Thriller'],
#  ['Graphic Novels',
#   'Comics',
#   'Horror',
#   'Zombies',
#   'Fiction',
#   'Graphic Novels Comics',
#   'Post Apocalyptic',
#   'Comic Book',
#   'Dystopia',
#   'Fantasy'],
#  ['Short Stories',
#   'Fiction',
#   'India',
#   'Contemporary',
#   'Literature',
#   'Literary Fiction',
#   'Indian Literature',
#   'Asia',
#   'Adult Fiction',
#   'Adult'],
#  ['Fantasy',
#   'Epic Fantasy',
#   'Fiction',
#   'Magic',
#   'Epic',
#   'Science Fiction Fantasy',
#   'Science Fiction',
#   'High Fantasy'],
#  ['Science Fiction',
#   'Fiction',
#   'Cyberpunk',
#   'Thriller',
#   'Science Fiction Fantasy',
#   'Audiobook',
#   'Mystery',
#   'Fantasy',
#   'Noir',
#   'Space Opera'],
#  ['Thriller',
#   'Fiction',
#   'Adventure',
#   'Mystery',
#   'Historical Fiction',
#   'Action',
#   'Suspense',
#   'Crime',
#   'Novels',
#   'Historical'],
#  ['Biography',
#   'Nonfiction',
#   'Ireland',
#   'History',
#   'Irish Literature',
#   'Biography Memoir',
#   'Literature',
#   'Literary Criticism',
#   'Criticism',
#   '20th Century'],
#  ['Travel',
#   'Nonfiction',
#   'Memoir',
#   'Biography',
#   'France',
#   'Italy',
#   'Biography Memoir',
#   'Womens',
#   'British Literature',
#   'Travelogue'],
#  ['Fiction',
#   'Crime',
#   'Historical Fiction',
#   'War',
#   'Thriller',
#   'Mystery',
#   'Coming Of Age',
#   'Contemporary',
#   'Politics',
#   'Action'],
#  ['Fantasy',
#   'Short Stories',
#   'Fiction',
#   'Classics',
#   'Mythology',
#   'Horror',
#   'Science Fiction Fantasy',
#   'British Literature',
#   'Poetry',
#   '20th Century'],
#  ['Science Fiction',
#   'Fiction',
#   'Alternate History',
#   'Science Fiction Fantasy',
#   'Novels',
#   'Historical',
#   'Dystopia',
#   'Politics',
#   'Mystery'],
#  ['Philosophy',
#   'Nonfiction',
#   'Science',
#   'Art',
#   'Psychology',
#   'Essays',
#   'Physics'],
#  ['Romance',
#   'Contemporary',
#   'Contemporary Romance',
#   'Adult',
#   'Chick Lit',
#   'Fiction',
#   'New Adult',
#   'Audiobook',
#   'Adult Fiction',
#   'Humor'],
#  ['Fantasy',
#   'Romance',
#   'Fiction',
#   'Epic Fantasy',
#   'Science Fiction Fantasy',
#   'Erotica',
#   'High Fantasy',
#   'Adult',
#   'Alternate History',
#   'BDSM'],
#  ['Historical Fiction',
#   'Mystery',
#   'Fiction',
#   'Historical',
#   'Historical Mystery',
#   'New York',
#   'Audiobook',
#   'Crime',
#   'Mystery Thriller',
#   'Adult'],
#  ['Vampires',
#   'Fiction',
#   'Fantasy',
#   'Horror',
#   'Supernatural',
#   'Paranormal',
#   'Historical Fiction',
#   'Classics',
#   'Romance',
#   'Humor'],
#  ['Young Adult',
#   'Contemporary',
#   'Realistic Fiction',
#   'Fiction',
#   'Young Adult Contemporary',
#   'Mental Health',
#   'Teen',
#   'Audiobook',
#   'Death',
#   'High School'],
#  ['Fantasy',
#   'Epic Fantasy',
#   'Fiction',
#   'High Fantasy',
#   'Dragons',
#   'Science Fiction Fantasy',
#   'Epic',
#   'Audiobook',
#   'Adult',
#   'Science Fiction'],
#  ['Science Fiction',
#   'Fiction',
#   'Horror',
#   'Vampires',
#   'Aliens',
#   'Space',
#   'Science Fiction Fantasy',
#   'Fantasy',
#   'Speculative Fiction',
#   'Hard Science Fiction'],
#  ['Fantasy',
#   'Young Adult',
#   'Fiction',
#   'Middle Grade',
#   'Humor',
#   'Childrens',
#   'Adventure',
#   'Audiobook',
#   'Urban Fantasy',
#   'Science Fiction'],
#  ['Manga',
#   'Fantasy',
#   'Romance',
#   'Graphic Novels',
#   'Shojo',
#   'Magic',
#   'Young Adult',
#   'Comics',
#   'Paranormal',
#   'Fiction'],
#  ['Fiction',
#   'Canada',
#   'Science Fiction',
#   'Dystopia',
#   'Novels',
#   'Contemporary',
#   'Post Apocalyptic',
#   'Adult Fiction',
#   'Canadian Literature',
#   'Philosophy'],
#  ['Mystery',
#   'Fiction',
#   'Romance',
#   'Adventure',
#   'Mystery Thriller',
#   'Crime',
#   'Suspense',
#   'Italy',
#   'Audiobook',
#   'Cozy Mystery'],
#  ['Fantasy',
#   'Young Adult',
#   'Adventure',
#   'Fiction',
#   'Young Adult Fantasy',
#   'Science Fiction Fantasy',
#   'Epic',
#   'Middle Grade',
#   'Childrens',
#   'High Fantasy'],
#  ['Nonfiction',
#   'Memoir',
#   'Books About Books',
#   'Biography',
#   'Biography Memoir',
#   'Autobiography',
#   'Family',
#   'Literature',
#   'Audiobook',
#   'Death'],
#  ['Music',
#   'Biography',
#   'Nonfiction',
#   'Autobiography',
#   'Memoir',
#   'Biography Memoir',
#   'Rock N Roll',
#   'Slash Fiction',
#   'Musicians',
#   'History'],
#  ['Young Adult',
#   'Contemporary',
#   'Romance',
#   'Realistic Fiction',
#   'Death',
#   'Chick Lit',
#   'Fiction',
#   'Teen',
#   'Young Adult Contemporary',
#   'Family'],
#  ['Fiction',
#   'Contemporary',
#   'Novels',
#   'American',
#   'Crime',
#   'Mystery',
#   'The United States Of America',
#   'Literature',
#   'Science Fiction',
#   'Literary Fiction'],
#  ['Romance',
#   'Dark',
#   'Erotica',
#   'Contemporary Romance',
#   'Contemporary',
#   'New Adult',
#   'Adult',
#   'Drama',
#   'Erotic Romance',
#   'Crime'],
#  ['Biography',
#   'Nonfiction',
#   'Biography Memoir',
#   'Film',
#   'Comedy',
#   'Music',
#   'Media Tie In',
#   'Pop Culture',
#   'Memoir',
#   'History'],
#  ['Young Adult',
#   'Science Fiction',
#   'Dystopia',
#   'Romance',
#   'Space',
#   'Fantasy',
#   'Adventure',
#   'Fiction',
#   'Teen',
#   'Young Adult Science Fiction'],
#  ['Fantasy',
#   'Young Adult',
#   'Romance',
#   'Fiction',
#   'Adventure',
#   'Magic',
#   'High Fantasy',
#   'Young Adult Fantasy',
#   'Paranormal',
#   'Fantasy Romance'],
#  ['Young Adult',
#   'Chick Lit',
#   'Contemporary',
#   'Fiction',
#   'Romance',
#   'Teen',
#   'Realistic Fiction',
#   'Young Adult Contemporary',
#   'Drama',
#   'Banned Books'],
#  ['Fiction',
#   'France',
#   'Classics',
#   'Literature',
#   'French Literature',
#   'Novels',
#   'Surreal',
#   'Art',
#   '20th Century',
#   'Romance'],
#  ['Urban Fantasy',
#   'Paranormal',
#   'Mythology',
#   'Fantasy',
#   'Magic',
#   'Adult',
#   'Supernatural',
#   'Romance',
#   'Paranormal Romance',
#   'Gods'],
#  ['Nonfiction',
#   'Spirituality',
#   'Self Help',
#   'Religion',
#   'Philosophy',
#   'Psychology',
#   'Christian',
#   'Leadership',
#   'Theology',
#   'Faith'],
#  ['Horror',
#   'Fiction',
#   'Ghosts',
#   'Paranormal',
#   'Mystery',
#   'Ghost Stories',
#   'Gothic',
#   'Supernatural',
#   'Thriller',
#   'Fantasy'],
#  ['Mystery',
#   'Cozy Mystery',
#   'Christmas',
#   'Historical Mystery',
#   'Historical Fiction',
#   'Fiction',
#   'Historical',
#   'British Literature',
#   'Mystery Thriller',
#   'Victorian'],
#  ['New Adult',
#   'Contemporary',
#   'Romance',
#   'LGBT',
#   'Mental Illness',
#   'Thriller',
#   'Dark',
#   'Mental Health',
#   'Fiction',
#   'Queer'],
#  ['Horror',
#   'Fiction',
#   'Thriller',
#   'Suspense',
#   'Mystery',
#   'Mystery Thriller',
#   'Crime',
#   'Adult',
#   'Audiobook',
#   'Novels'],
#  ['Science Fiction',
#   'Fiction',
#   'Classics',
#   'Military Fiction',
#   'War',
#   'Science Fiction Fantasy',
#   'Space Opera',
#   'Fantasy',
#   'Space',
#   'Audiobook'],
#  ['Historical Fiction',
#   'Fiction',
#   'Australia',
#   'Historical',
#   'Book Club',
#   'Literary Fiction',
#   'Literature',
#   'Novels',
#   'Audiobook',
#   '19th Century'],
#  ['Nonfiction',
#   'Memoir',
#   'Contemporary',
#   'Biography',
#   'Humor',
#   'Teen',
#   'Middle Grade',
#   'Biography Memoir',
#   'Autobiography',
#   'Coming Of Age'],
#  ['Biography',
#   'Christian',
#   'Nonfiction',
#   'Autobiography',
#   'Christianity',
#   'Religion',
#   'Christian Non Fiction',
#   'Faith',
#   'Biography Memoir',
#   'History'],
#  ['Nonfiction',
#   'Vampires',
#   'Humor',
#   'Horror',
#   'History',
#   'Pop Culture',
#   'Travel',
#   'Supernatural',
#   'Cultural',
#   'Folklore'],
#  ['Romance',
#   'Sports',
#   'Sports Romance',
#   'Contemporary Romance',
#   'Contemporary',
#   'Erotica',
#   'Adult',
#   'Baseball',
#   'Erotic Romance',
#   'Fiction'],
#  ['Fantasy', 'Young Adult', 'Magic', 'Fiction', 'Family', 'Urban Fantasy'],
#  ['Historical Fiction',
#   'Fiction',
#   'Historical',
#   'Horror',
#   'British Literature'],
#  ['Fantasy',
#   'Fiction',
#   'Historical Fiction',
#   'Science Fiction Fantasy',
#   'Science Fiction',
#   'Historical',
#   'Adventure',
#   'Alternate History',
#   'Romance',
#   'Historical Fantasy'],
#  ['Chick Lit',
#   'Romance',
#   'Fiction',
#   'Adult',
#   'Australia',
#   'Audiobook',
#   'Adult Fiction',
#   'Contemporary',
#   'Novels'],
#  ['Fiction',
#   'Romance',
#   'Classics',
#   'Chick Lit',
#   'Contemporary',
#   'Novels',
#   'Adult Fiction',
#   'Adult',
#   'Love',
#   'Drama'],
#  ['Fiction',
#   'Music',
#   'Humor',
#   'Contemporary',
#   'Crime',
#   'Comedy',
#   'Novels',
#   'Thriller',
#   'Modern',
#   'Literature'],
#  ['Baseball',
#   'Sports',
#   'Biography',
#   'Nonfiction',
#   'History',
#   'Biography Memoir',
#   'Inspirational',
#   'Audiobook',
#   'American History',
#   'Unfinished'],
#  ['Fiction',
#   'Contemporary',
#   'Feminism',
#   'American',
#   'Literary Fiction',
#   'The United States Of America',
#   'Novels',
#   'Womens',
#   'Literature',
#   'Roman'],
#  ['Christian',
#   'Religion',
#   'Nonfiction',
#   'Christianity',
#   'Reference',
#   'Spirituality',
#   'Faith',
#   'Christian Non Fiction',
#   'Classics',
#   'History'],
#  ['Science',
#   'Nonfiction',
#   'Astronomy',
#   'Physics',
#   'Space',
#   'Philosophy',
#   'Popular Science',
#   'History Of Science',
#   'Education',
#   'Essays'],
#  ['Fiction',
#   'Historical Fiction',
#   'Historical',
#   'Literary Fiction',
#   'British Literature',
#   'Literature',
#   'Contemporary',
#   'Novels',
#   'Classics',
#   'Audiobook'],
#  ['Fantasy',
#   'Dragons',
#   'Young Adult',
#   'Fiction',
#   'Middle Grade',
#   'Magic',
#   'Childrens',
#   'Adventure',
#   'Urban Fantasy',
#   'Juvenile'],
#  ['Manga',
#   'Romance',
#   'Shojo',
#   'Graphic Novels',
#   'Comedy',
#   'Comics',
#   'Young Adult',
#   'Humor',
#   'Slice Of Life',
#   'Manga Romance'],
#  ['Vampires',
#   'Paranormal',
#   'Young Adult',
#   'Fantasy',
#   'Fiction',
#   'Romance',
#   'Supernatural',
#   'Urban Fantasy',
#   'Paranormal Romance',
#   'Love'],
#  ['Comics',
#   'Graphic Novels',
#   'Science Fiction',
#   'Steampunk',
#   'Fantasy',
#   'Fiction',
#   'Alternate History',
#   'Adventure',
#   'Comix',
#   'Historical Fiction'],
#  ['Paganism',
#   'History',
#   'Biography',
#   'Magick',
#   'Witchcraft',
#   'Nonfiction',
#   'Religion'],
#  ['Historical Fiction',
#   'Fiction',
#   'Mystery',
#   'Italy',
#   'Historical',
#   'World War II',
#   'War',
#   'Audiobook',
#   'Adult Fiction',
#   'Suspense'],
#  ['Thriller', 'Mythology'],
#  ['Finance', 'Nonfiction', 'Psychology', 'Business', 'Economics'],
#  ['Philosophy',
#   'Science',
#   'Nonfiction',
#   'Religion',
#   'Psychology',
#   'Atheism',
#   'Neuroscience',
#   'Sociology',
#   'Audiobook',
#   'Politics'],
#  ['Christian Living',
#   'Christian',
#   'Prayer',
#   'Faith',
#   'Nonfiction',
#   'Spirituality',
#   'Christian Non Fiction',
#   'Religion'],
#  ['Philosophy',
#   'Nonfiction',
#   'France',
#   'Romanian Literature',
#   'Essays',
#   'Romania',
#   '20th Century',
#   'Literature',
#   'Classics',
#   'Psychology'],
#  ['Young Adult',
#   'Fiction',
#   'Realistic Fiction',
#   'Chick Lit',
#   'Romance',
#   'Teen',
#   'Contemporary',
#   'High School',
#   'Family',
#   'Humor'],
#  ['Mystery',
#   'Crime',
#   'Fiction',
#   'British Literature',
#   'Archaeology',
#   'Historical Fiction',
#   'Mystery Thriller',
#   'Detective',
#   'Historical Mystery',
#   'Thriller'],
#  ['Young Adult',
#   'Fantasy',
#   'Romance',
#   'Paranormal',
#   'Werewolves',
#   'Fiction',
#   'Urban Fantasy',
#   'Supernatural',
#   'Paranormal Romance',
#   'Audiobook'],
#  ['Poetry',
#   'Classics',
#   'Fiction',
#   'Historical Fiction',
#   'Literature',
#   'Fantasy',
#   'Mythology',
#   'Childrens',
#   'Picture Books',
#   'American'],
#  ['Amish',
#   'Romance',
#   'Love Inspired',
#   'Christian Fiction',
#   'Christian',
#   'Contemporary',
#   'Fiction',
#   'Contemporary Romance',
#   'Religion',
#   'Amish Fiction'],
#  ['Historical Fiction',
#   'Fiction',
#   'Historical',
#   'Romance',
#   'Classics',
#   'Historical Romance',
#   'Novels',
#   'Adult Fiction',
#   'Literature',
#   'British Literature'],
#  ['Fiction',
#   'Thriller',
#   'Mystery',
#   'Contemporary',
#   'Suspense',
#   'Africa',
#   'Adult Fiction',
#   'Mystery Thriller',
#   'Historical Fiction',
#   'Novels'],
#  ['Young Adult',
#   'Paranormal',
#   'Mystery',
#   'Ghosts',
#   'Fantasy',
#   'Romance',
#   'Supernatural',
#   'Magic',
#   'Teen',
#   'Adventure'],
#  ['Cookbooks',
#   'Cooking',
#   'Nonfiction',
#   'Food',
#   'Parenting',
#   'Health',
#   'Reference',
#   'Nutrition',
#   'Childrens',
#   'Amazon'],
#  ['Christian Fiction',
#   'Historical Fiction',
#   'Romance',
#   'Christian',
#   'Historical',
#   'Fiction',
#   'Historical Romance',
#   'Christian Romance',
#   'Chick Lit',
#   'Christian Historical Fiction'],
#  ['Classics', 'Historical Fiction', 'Fiction'],
#  ['Fantasy',
#   'Fiction',
#   'Humor',
#   'Comedy',
#   'Science Fiction Fantasy',
#   'Audiobook',
#   'Death',
#   'Magic',
#   'Novels',
#   'Science Fiction'],
#  ['Historical Fiction',
#   'Christian Fiction',
#   'Fiction',
#   'Historical',
#   'Christian',
#   'Civil War',
#   'American Civil War',
#   'Adult Fiction',
#   'Chick Lit',
#   'Christian Historical Fiction'],
#  ['Fantasy',
#   'Young Adult',
#   'Magic',
#   'Dragons',
#   'Fiction',
#   'Adventure',
#   'Childrens',
#   'Middle Grade',
#   'Novels',
#   'Juvenile'],
#  ['Young Adult',
#   'Paranormal',
#   'Ghosts',
#   'Fantasy',
#   'Romance',
#   'Supernatural',
#   'Urban Fantasy',
#   'Paranormal Romance',
#   'Fiction',
#   'Young Adult Paranormal'],
#  ['Nonfiction',
#   'Sociology',
#   'Psychology',
#   'Cultural',
#   'Science',
#   'Pop Culture',
#   'Technology',
#   'Education',
#   'Business',
#   'Philosophy'],
#  ['Mystery',
#   'Gothic',
#   'Romance',
#   'Fiction',
#   'Historical Fiction',
#   'Romantic Suspense',
#   'Gothic Romance',
#   'Historical',
#   'Suspense',
#   'Mystery Thriller'],
#  ['Paranormal Romance',
#   'Paranormal',
#   'Romance',
#   'Fantasy',
#   'Urban Fantasy',
#   'Shapeshifters',
#   'Adult',
#   'Science Fiction',
#   'Fiction',
#   'Werewolves'],
#  ['Steampunk',
#   'Romance',
#   'Fantasy',
#   'Paranormal',
#   'Vampires',
#   'Historical',
#   'Paranormal Romance',
#   'Historical Romance',
#   'Supernatural',
#   'Fiction'],
#  ['Thriller',
#   'Horror',
#   'Fiction',
#   'Suspense',
#   'Mystery',
#   'Mystery Thriller',
#   'Crime',
#   'Audiobook',
#   'Adult',
#   'Espionage'],
#  ['Romance',
#   'Historical Romance',
#   'Time Travel',
#   'Historical',
#   'Historical Fiction',
#   'Fiction',
#   'Fantasy',
#   'Medieval',
#   'Time Travel Romance',
#   'Contemporary'],
#  ['Economics',
#   'Nonfiction',
#   'History',
#   'Finance',
#   'Business',
#   'Politics',
#   'Money',
#   'American History',
#   'Banking',
#   'Collections'],
#  ['Romance',
#   'Contemporary Romance',
#   'Contemporary',
#   'Adult',
#   'Audiobook',
#   'New Adult',
#   'Humor',
#   'Fiction',
#   'Chick Lit',
#   'Erotica'],
#  ['Nonfiction',
#   'Philosophy',
#   'Spirituality',
#   'Religion',
#   'Psychology',
#   'Science',
#   'Self Help',
#   'Atheism',
#   'Audiobook',
#   'Buddhism'],
#  ['Chick Lit',
#   'Romance',
#   'Contemporary',
#   'Fiction',
#   'Adult',
#   'Humor',
#   'Adult Fiction',
#   'Contemporary Romance',
#   'Audiobook',
#   'Womens Fiction'],
#  ['Fiction',
#   'France',
#   'Romance',
#   'Roman',
#   'French Literature',
#   'Contemporary',
#   'Classics',
#   'Novels',
#   'Russia',
#   '20th Century'],
#  ['Fiction',
#   'Italian Literature',
#   'Classics',
#   'Italy',
#   'Literature',
#   'Novels',
#   '20th Century',
#   'Roman',
#   'Magical Realism',
#   'War'],
#  ['Comics',
#   'Graphic Novels',
#   'Marvel',
#   'LGBT',
#   'Fantasy',
#   'Graphic Novels Comics',
#   'Comic Book',
#   'Superheroes',
#   'Queer',
#   'Romance'],
#  ['Historical Fiction',
#   'Poetry',
#   'Young Adult',
#   'Historical',
#   'Fiction',
#   'Teen',
#   'Death',
#   'Realistic Fiction',
#   'Audiobook',
#   'Adult'],
#  ['Fiction',
#   'African American',
#   'Historical Fiction',
#   'Classics',
#   'Race',
#   'New York',
#   'Novels',
#   'American',
#   'Young Adult',
#   'African American Literature'],
#  ['Classics',
#   'Fiction',
#   'Literature',
#   '18th Century',
#   'British Literature',
#   'Humor',
#   'Novels',
#   'Historical Fiction',
#   'Romance',
#   'English Literature'],
#  ['Fiction',
#   'Classics',
#   'Feminism',
#   'Literature',
#   'Novels',
#   'Nobel Prize',
#   'Womens',
#   'Literary Fiction',
#   'British Literature',
#   '20th Century'],
#  ['Poetry'],
#  ['Science Fiction',
#   'Fiction',
#   'Science Fiction Fantasy',
#   'Classics',
#   'Hugo Awards',
#   'Fantasy',
#   'Novels',
#   'Aliens',
#   'Space',
#   'Audiobook'],
#  ['Romance',
#   'Fiction',
#   'Paranormal',
#   'Contemporary Romance',
#   'Contemporary',
#   'Chick Lit',
#   'Paranormal Romance',
#   'Mystery',
#   'Fantasy',
#   'Ghosts'],
#  ['Fiction',
#   'India',
#   'Indian Literature',
#   'Religion',
#   'Classics',
#   'Literature',
#   'Asia',
#   'Novels',
#   'Philosophy',
#   '20th Century'],
#  ['New Adult',
#   'Romance',
#   'Contemporary',
#   'Erotica',
#   'Contemporary Romance',
#   'Young Adult',
#   'Humor',
#   'Fiction',
#   'Amazon',
#   'Coming Of Age'],
#  ['Short Stories', 'Fiction'],
#  ['Young Adult',
#   'Contemporary',
#   'Romance',
#   'Fiction',
#   'Realistic Fiction',
#   'Death',
#   'Teen',
#   'Drama',
#   'Young Adult Contemporary',
#   'Chick Lit'],
#  ['Fiction',
#   'Fantasy',
#   'Short Stories',
#   'Childrens',
#   'Classics',
#   'Poetry',
#   'Fairy Tales',
#   'American',
#   'Juvenile',
#   'Humor'],
#  ['Historical Fiction',
#   'Young Adult',
#   'Fiction',
#   'Historical',
#   'Romance',
#   'Audiobook',
#   'Spain',
#   'Teen',
#   'Young Adult Historical Fiction',
#   'War'],
#  ['Plays',
#   'Classics',
#   'Drama',
#   'Mythology',
#   'Theatre',
#   'Fiction',
#   'Ancient',
#   'Tragedy',
#   'Poetry',
#   'Ancient History'],
#  ['History',
#   'Africa',
#   'Military History',
#   'Nonfiction',
#   'War',
#   'Military Fiction',
#   'South Africa',
#   'British Literature',
#   'World History',
#   'European History'],
#  ['Fiction',
#   'Contemporary',
#   'Southern',
#   'Coming Of Age',
#   'Mystery',
#   'Death',
#   'Adult Fiction',
#   'Historical',
#   'Historical Fiction'],
#  ['Christian Fiction',
#   'Romance',
#   'Christian',
#   'Contemporary',
#   'Mystery',
#   'Suspense',
#   'Clean Romance',
#   'Adventure',
#   'Historical Fiction',
#   'Novels'],
#  ['Nonfiction',
#   'Biography',
#   'Autobiography',
#   'True Crime',
#   'Crime',
#   'Memoir',
#   'Drama',
#   'Thriller',
#   'Politics',
#   'Mystery'],
#  ['Fantasy',
#   'Fiction',
#   'Humor',
#   'Science Fiction Fantasy',
#   'Young Adult',
#   'Magic',
#   'Adventure',
#   'Science Fiction',
#   'Adult',
#   'Comedy'],
#  ['Fantasy',
#   'Young Adult',
#   'Romance',
#   'Fairy Tales',
#   'Fiction',
#   'Retellings',
#   'Historical Fiction',
#   'Magic',
#   'Vampires',
#   'Young Adult Fantasy'],
#  ['Historical Fiction',
#   'Fiction',
#   'Historical',
#   'Iran',
#   '16th Century',
#   'Audiobook',
#   'Feminism',
#   'Womens',
#   'Novels',
#   'Literary Fiction'],
#  ['Comics',
#   'Graphic Novels',
#   'Horror',
#   'Fantasy',
#   'Fiction',
#   'Comic Book',
#   'Graphic Novels Comics',
#   'Supernatural',
#   'Comix',
#   'Paranormal'],
#  ['Fantasy',
#   'Young Adult',
#   'Mythology',
#   'Fiction',
#   'Adventure',
#   'Young Adult Fantasy',
#   'Childrens',
#   'Science Fiction',
#   'Urban Fantasy',
#   'Middle Grade'],
#  ['Doctor Who', 'Science Fiction', 'Fiction', 'Fantasy'],
#  ['Poetry',
#   'Classics',
#   'Romance',
#   '19th Century',
#   'Victorian',
#   'British Literature',
#   'Literature',
#   'Nonfiction',
#   'Womens',
#   'Classic Literature'],
#  ['Fiction',
#   'Classics',
#   'Literature',
#   'Novels',
#   'Scandinavian Literature',
#   'Nobel Prize',
#   'Drama',
#   '20th Century',
#   'Mystery',
#   'Thriller'],
#  ['Fiction',
#   'Contemporary',
#   'Adult',
#   'Adult Fiction',
#   'Family',
#   'Romance',
#   'Audiobook',
#   'Marriage',
#   'Relationships',
#   'Novels'],
#  ['Fiction',
#   'Humor',
#   'Classics',
#   'Comedy',
#   'British Literature',
#   'Novels',
#   'Literature',
#   'Audiobook',
#   'Romance',
#   '20th Century'],
#  ['Mystery',
#   'Fiction',
#   'Thriller',
#   'Suspense',
#   'Horror',
#   'Crime',
#   'Mystery Thriller',
#   'Detective',
#   'Religion',
#   'Christian'],
#  ['Young Adult',
#   'Fiction',
#   'Family',
#   'Realistic Fiction',
#   'Young Adult Contemporary'],
#  ['Romance',
#   'Historical Fiction',
#   'Young Adult',
#   'Fantasy',
#   'Christian Fiction',
#   'Christian',
#   'Fairy Tales',
#   'Historical',
#   'Fiction',
#   'Retellings'],
#  ['Young Adult',
#   'Fantasy',
#   'Paranormal',
#   'Magic',
#   'Witches',
#   'Romance',
#   'Fiction',
#   'Urban Fantasy',
#   'Supernatural',
#   'Paranormal Romance'],
#  ['Thriller',
#   'Fiction',
#   'Adventure',
#   'Action',
#   'Mystery',
#   'Fantasy',
#   'Mystery Thriller',
#   'Suspense',
#   'Military Fiction',
#   'Historical Fiction'],
#  ['Fiction',
#   'Humor',
#   'Science Fiction',
#   'Classics',
#   'Literature',
#   'Novels',
#   'American',
#   'Literary Fiction',
#   'Contemporary',
#   '20th Century'],
#  ['Business',
#   'Reference',
#   'Nonfiction',
#   'Management',
#   'Productivity',
#   'Education',
#   'Self Help',
#   'Leadership'],
#  ['Fiction',
#   'Humor',
#   'Childrens',
#   'Realistic Fiction',
#   'Middle Grade',
#   'Graphic Novels',
#   'Young Adult',
#   'Comedy',
#   'Comics',
#   'Contemporary'],
#  ['History',
#   'World War I',
#   'Nonfiction',
#   'Military History',
#   'War',
#   'Military Fiction',
#   'Historical',
#   '20th Century',
#   'European History',
#   'France'],
#  ['Fantasy',
#   'Young Adult',
#   'Romance',
#   'Paranormal',
#   'Fae',
#   'Fairies',
#   'Magic',
#   'Urban Fantasy',
#   'Young Adult Fantasy',
#   'Fiction'],
#  ['Mystery',
#   'Historical Fiction',
#   'Historical',
#   'Historical Mystery',
#   'Ireland',
#   'Fiction',
#   'Crime',
#   'Medieval',
#   'Detective',
#   'Irish Literature'],
#  ['Classics',
#   'Fiction',
#   'France',
#   'French Literature',
#   '19th Century',
#   'Historical Fiction',
#   'War',
#   'Novels',
#   'Literature',
#   'Historical'],
#  ['Urban Fantasy',
#   'Fantasy',
#   'Paranormal',
#   'Demons',
#   'Romance',
#   'Magic',
#   'Paranormal Romance',
#   'Fiction',
#   'Supernatural',
#   'Adult'],
#  ['Science Fiction',
#   'Fantasy',
#   'Superheroes',
#   'Fiction',
#   'Anthologies',
#   'Urban Fantasy',
#   'Alternate History',
# ...
#   'History',
#   'Essays',
#   'Classics',
#   'Literature',
#   'Psychology',
#   'Reference',
#   'Anthologies',
#   'Academic'],
#  ['Mystery',
#   'Fiction',
#   'Classics',
#   'Short Stories',
#   'Crime',
#   'Detective',
#   'Audiobook',
#   'British Literature',
#   'Christian',
#   'Mystery Thriller'],
#  ['Fantasy'],
#  ['Paranormal Romance',
#   'Vampires',
#   'Paranormal',
#   'Romance',
#   'Fantasy',
#   'Christmas',
#   'Fiction',
#   'Urban Fantasy',
#   'Adult',
#   'Supernatural'],
#  ['Urban Fantasy',
#   'Fantasy',
#   'Angels',
#   'Paranormal',
#   'Demons',
#   'Paranormal Romance',
#   'Romance',
#   'Urban',
#   'Adult',
#   'Magic'],
#  ['Historical Fiction',
#   'Young Adult',
#   'Mystery',
#   'Ghosts',
#   'Historical',
#   'Paranormal',
#   'Fantasy',
#   'Civil War',
#   'Romance',
#   'Horror'],
#  ['Young Adult',
#   'Dystopia',
#   'Science Fiction',
#   'Historical Fiction',
#   'Teen',
#   'LGBT',
#   'Alternate History',
#   'Fantasy',
#   'Historical',
#   'Mystery'],
#  ['Historical Fiction',
#   'Young Adult',
#   'Fiction',
#   'Childrens',
#   'Middle Grade',
#   'Humor',
#   'Historical',
#   'Juvenile',
#   'Realistic Fiction',
#   'Family'],
#  ['Historical Fiction',
#   'Fiction',
#   'Australia',
#   'Historical',
#   'Audiobook',
#   'Adult',
#   'Novels',
#   'Adventure',
#   'Literature',
#   '19th Century'],
#  ['Fiction',
#   'Historical Fiction',
#   'Gothic',
#   'Historical',
#   'Literary Fiction',
#   'Adult',
#   'Romance',
#   'Novels',
#   'Mystery',
#   'British Literature'],
#  ['Romance',
#   'Romantic Suspense',
#   'Contemporary Romance',
#   'Contemporary',
#   'Fiction',
#   'Paranormal',
#   'Suspense',
#   'Mystery',
#   'Military Romance',
#   'Military Fiction'],
#  ['Fantasy',
#   'Fiction',
#   'Epic Fantasy',
#   'Science Fiction Fantasy',
#   'High Fantasy',
#   'Dragons',
#   'Science Fiction',
#   'Adult',
#   'Epic',
#   'Magic'],
#  ['Horror',
#   'Fiction',
#   'Thriller',
#   'Mystery',
#   'Suspense',
#   'Supernatural',
#   'Adult',
#   'Mystery Thriller',
#   'Audiobook',
#   'Romance'],
#  ['Fantasy',
#   'Young Adult',
#   'Fiction',
#   'Magic',
#   'Adventure',
#   'Young Adult Fantasy',
#   'Mystery',
#   'Romance',
#   'High Fantasy',
#   'Teen'],
#  ['Spirituality',
#   'Biography',
#   'Nonfiction',
#   'Autobiography',
#   'Philosophy',
#   'Religion',
#   'Memoir',
#   'Taoism',
#   'Buddhism'],
#  ['Fiction',
#   'Dystopia',
#   'Science Fiction',
#   'Adult',
#   'Adult Fiction',
#   'Feminism',
#   'Young Adult',
#   'Religion',
#   'Fantasy',
#   'Audiobook'],
#  ['Mystery',
#   'Thriller',
#   'Crime',
#   'Fiction',
#   'Suspense',
#   'Mystery Thriller',
#   'Murder Mystery',
#   'Detective',
#   'Audiobook',
#   'Adult'],
#  ['Young Adult',
#   'Dystopia',
#   'Science Fiction',
#   'Fiction',
#   'Post Apocalyptic',
#   'Apocalyptic',
#   'Survival',
#   'Horror',
#   'Fantasy',
#   'Teen'],
#  ['Sports',
#   'Nonfiction',
#   'Biography',
#   'Football',
#   'Adult',
#   'Biography Memoir',
#   'Business',
#   'Media Tie In',
#   'Memoir',
#   'Audiobook'],
#  ['Religion',
#   'Lds',
#   'Nonfiction',
#   'History',
#   'Church',
#   'Inspirational',
#   'Christian',
#   'Spirituality',
#   'Lds Non Fiction'],
#  ['LGBT',
#   'Fiction',
#   'Historical Fiction',
#   'Gay',
#   'Historical',
#   'Queer',
#   'Ireland',
#   'Romance',
#   'Irish Literature',
#   'M M Romance'],
#  ['Poetry',
#   'Nonfiction',
#   'Music',
#   '20th Century',
#   'Philosophy',
#   'Short Stories',
#   'Collections',
#   'Essays',
#   'Memoir',
#   'Biography Memoir'],
#  ['Horror',
#   'Fantasy',
#   'Fiction',
#   'Dark Fantasy',
#   'Science Fiction',
#   'Thriller',
#   'Supernatural',
#   'Urban Fantasy',
#   'Suspense',
#   'Science Fiction Fantasy'],
#  ['Nonfiction',
#   'Self Help',
#   'Business',
#   'Productivity',
#   'Psychology',
#   'Personal Development',
#   'Audiobook',
#   'Leadership',
#   'Management',
#   'Writing'],
#  ['Mystery',
#   'Historical Fiction',
#   'Fiction',
#   'Historical',
#   'Historical Mystery',
#   'Audiobook',
#   'British Literature',
#   'Mystery Thriller',
#   'Crime',
#   'World War I'],
#  ['Thriller',
#   'Adventure',
#   'Fiction',
#   'Crime',
#   'Mystery',
#   'Mystery Thriller',
#   'Action',
#   'Historical Fiction',
#   'Military Fiction',
#   'Suspense'],
#  ['Fantasy',
#   'Fiction',
#   'Epic Fantasy',
#   'Science Fiction Fantasy',
#   'High Fantasy',
#   'Magic',
#   'Adventure',
#   'Romance',
#   'Epic',
#   'Adult'],
#  ['Historical Fiction',
#   'War',
#   'Young Adult',
#   'Fiction',
#   'Historical',
#   'Novels',
#   'Childrens',
#   'School',
#   'Family',
#   'World War I'],
#  ['Young Adult',
#   'Chick Lit',
#   'Realistic Fiction',
#   'Middle Grade',
#   'Fiction',
#   'Contemporary',
#   'Romance',
#   'Childrens',
#   'Teen',
#   'Adult'],
#  ['Horror', 'Dark', 'Crime', 'Abuse', 'Fiction'],
#  ['Poetry',
#   'Fiction',
#   'France',
#   'Classics',
#   'Literature',
#   'French Literature',
#   'Horror',
#   'Surreal',
#   '19th Century',
#   'Fantasy'],
#  ['Young Adult',
#   'Dystopia',
#   'Science Fiction',
#   'Short Stories',
#   'Fiction',
#   'Fantasy',
#   'Anthologies',
#   'Teen',
#   'Horror',
#   'Survival'],
#  ['Young Adult',
#   'Horror',
#   'Mystery',
#   'Paranormal',
#   'Ghosts',
#   'Historical Fiction',
#   'Fantasy',
#   'Supernatural',
#   'Fiction',
#   'Middle Grade'],
#  ['Fantasy',
#   'Fiction',
#   'Shapeshifters',
#   'Amazon',
#   'Epic Fantasy',
#   'Science Fiction Fantasy',
#   'Romance',
#   'Reference',
#   'Paranormal',
#   'Magic'],
#  ['Fiction',
#   'Classics',
#   'German Literature',
#   'Literature',
#   'Historical Fiction',
#   'Germany',
#   'Religion',
#   'Novels',
#   '20th Century',
#   'Egypt'],
#  ['Thriller',
#   'Mystery',
#   'Suspense',
#   'Crime',
#   'Fiction',
#   'Mystery Thriller',
#   'Action',
#   'Romantic Suspense',
#   'Adult',
#   'Adventure'],
#  ['Young Adult',
#   'Dystopia',
#   'Science Fiction',
#   'Middle Grade',
#   'Adventure',
#   'Fiction',
#   'Childrens',
#   'Survival',
#   'Teen',
#   'Post Apocalyptic'],
#  ['Fiction',
#   'Romance',
#   'Contemporary',
#   'Contemporary Romance',
#   'Novels',
#   'Love Story',
#   'Chick Lit',
#   'Love',
#   'American'],
#  ['Mystery',
#   'Young Adult',
#   'Thriller',
#   'Mystery Thriller',
#   'Contemporary',
#   'Fiction',
#   'Audiobook',
#   'Suspense',
#   'Teen',
#   'Young Adult Contemporary'],
#  ['Mystery',
#   'Young Adult',
#   'Middle Grade',
#   'Fiction',
#   'Childrens',
#   'Realistic Fiction',
#   'Juvenile',
#   'Adventure',
#   'Mystery Thriller',
#   'Contemporary'],
#  ['Fantasy',
#   'Fiction',
#   'Science Fiction Fantasy',
#   'High Fantasy',
#   'Magic',
#   'Epic Fantasy',
#   'Adult',
#   'Science Fiction',
#   'Young Adult',
#   'Novels'],
#  ['Fiction',
#   'Italy',
#   'War',
#   'Italian Literature',
#   'World War II',
#   'Historical Fiction',
#   'Literature',
#   'Classics',
#   '20th Century',
#   'Novels'],
#  ['Fantasy',
#   'Young Adult',
#   'Fairy Tales',
#   'Historical Fiction',
#   'Retellings',
#   'Fiction',
#   'Romance',
#   'Historical',
#   'Magic',
#   'Fairy Tale Retellings'],
#  ['Gardening',
#   'Nature',
#   'Nonfiction',
#   'Science',
#   'Plants',
#   'Environment',
#   'Sustainability',
#   'Horticulture',
#   'Reference',
#   'Biology'],
#  ['Nonfiction',
#   'History',
#   'Books About Books',
#   'Essays',
#   'Literature',
#   'Philosophy',
#   'Writing',
#   'Literary Criticism',
#   'Cultural',
#   'Canada'],
#  ['Fantasy',
#   'Classics',
#   'Childrens',
#   'Fiction',
#   'Young Adult',
#   'Adventure',
#   'Middle Grade',
#   'Time Travel',
#   'Childrens Classics',
#   'Audiobook'],
#  ['Young Adult',
#   'Fantasy',
#   'Mermaids',
#   'Romance',
#   'Paranormal',
#   'Supernatural',
#   'Paranormal Romance',
#   'Mythology',
#   'Fiction',
#   'Teen'],
#  ['Fantasy',
#   'Fiction',
#   'Epic Fantasy',
#   'High Fantasy',
#   'Science Fiction Fantasy',
#   'Adventure',
#   'Magic',
#   'Dragons',
#   'Epic',
#   'Adult'],
#  ['Horror',
#   'Thriller',
#   'Fiction',
#   'Suspense',
#   'Science Fiction',
#   'Fantasy',
#   'Apocalyptic',
#   'New York',
#   'Dystopia',
#   'Adventure'],
#  ['Horror',
#   'Fiction',
#   'Mystery',
#   'Thriller',
#   'Suspense',
#   'Paranormal',
#   'Adult',
#   'Supernatural',
#   'Mystery Thriller',
#   'Novels'],
#  ['Mystery',
#   'Thriller',
#   'Fiction',
#   'Suspense',
#   'Crime',
#   'Mystery Thriller',
#   'Drama',
#   'Audiobook',
#   'Adult',
#   'Novels'],
#  ['Fiction',
#   'Middle Grade',
#   'Young Adult',
#   'Childrens',
#   'Realistic Fiction',
#   'Animals',
#   'Juvenile',
#   'Fantasy',
#   'Contemporary',
#   'School'],
#  ['Historical Fiction',
#   'Fantasy',
#   'Fiction',
#   'Arthurian',
#   'Historical',
#   'Medieval',
#   'Mythology',
#   'Historical Fantasy',
#   'Adventure',
#   'British Literature'],
#  ['Childrens',
#   'Adventure',
#   'Fiction',
#   'Mystery',
#   'Classics',
#   'Young Adult',
#   'Middle Grade',
#   'British Literature',
#   'Novels',
#   'Juvenile'],
#  ['Thriller',
#   'Fiction',
#   'Mystery',
#   'Crime',
#   'Adventure',
#   'Religion',
#   'Suspense',
#   'Historical Fiction',
#   'Mystery Thriller',
#   'Action'],
#  ['Holocaust',
#   'Nonfiction',
#   'History',
#   'Biography',
#   'Memoir',
#   'World War II',
#   'Autobiography',
#   'Historical',
#   'War',
#   'Jewish'],
#  ['Horror',
#   'Zombies',
#   'Humor',
#   'Fiction',
#   'Science Fiction',
#   'Fantasy',
#   'Comedy',
#   'Apocalyptic',
#   'Post Apocalyptic',
#   'Dystopia'],
#  ['Fiction',
#   'Horror',
#   'Audiobook',
#   'Mystery',
#   'Religion',
#   'Paranormal',
#   'Thriller'],
#  ['History',
#   'Nonfiction',
#   'Aviation',
#   'World War II',
#   'Military History',
#   'War',
#   'Military Fiction',
#   'Historical',
#   'Germany',
#   'European History'],
#  ['Fantasy',
#   'Young Adult',
#   'Romance',
#   'Mythology',
#   'Paranormal',
#   'Magic',
#   'Adventure',
#   'Fiction',
#   'Time Travel',
#   'Paranormal Romance'],
#  ['Zombies',
#   'Horror',
#   'Post Apocalyptic',
#   'Fiction',
#   'Dystopia',
#   'Young Adult',
#   'Fantasy',
#   'Science Fiction',
#   'Apocalyptic',
#   'Paranormal'],
#  ['Historical Fiction', 'Historical', 'Fiction', 'World War I', 'Romance'],
#  ['Fantasy',
#   'Young Adult',
#   'Childrens',
#   'Romance',
#   'Fiction',
#   'Adventure',
#   'Middle Grade',
#   'Magic',
#   'Young Adult Fantasy',
#   'Teen'],
#  ['Manga',
#   'Graphic Novels',
#   'Comics',
#   'Fantasy',
#   'Science Fiction',
#   'Fiction',
#   'Graphic Novels Comics',
#   'Adventure',
#   'Japan',
#   'Comic Book'],
#  ['Romance',
#   'Romantic Suspense',
#   'Military Fiction',
#   'Erotica',
#   'Contemporary Romance',
#   'Contemporary',
#   'Suspense',
#   'Erotic Romance',
#   'Military Romance',
#   'Adult'],
#  ['Poetry',
#   'Classics',
#   'Fantasy',
#   'Fiction',
#   '19th Century',
#   'Victorian',
#   'Literature',
#   'Fairy Tales',
#   'British Literature',
#   'Gothic'],
#  ['Vampires',
#   'Young Adult',
#   'Paranormal',
#   'Fantasy',
#   'Angels',
#   'Romance',
#   'Supernatural',
#   'Urban Fantasy',
#   'Fiction',
#   'Teen'],
#  ['Middle Grade',
#   'Realistic Fiction',
#   'Contemporary',
#   'Fiction',
#   'School',
#   'Disability',
#   'Childrens',
#   'Family',
#   'Young Adult',
#   'Audiobook'],
#  ['Psychology'],
#  ['Horror',
#   'Thriller',
#   'Mystery',
#   'Fantasy',
#   'Crime',
#   'Fiction',
#   'Contemporary',
#   'Noir',
#   'Ghosts',
#   'Young Adult'],
#  ['Young Adult',
#   'Science Fiction',
#   'Dystopia',
#   'Romance',
#   'Fantasy',
#   'Fiction',
#   'Mystery',
#   'Space',
#   'Teen',
#   'Futuristic'],
#  ['Young Adult',
#   'Romance',
#   'Contemporary',
#   'Fiction',
#   'Audiobook',
#   'Chick Lit',
#   'Young Adult Contemporary',
#   'Realistic Fiction',
#   'High School',
#   'Young Adult Romance'],
#  ['Philosophy',
#   'Politics',
#   'Nonfiction',
#   'Classics',
#   'Sociology',
#   'France',
#   'History',
#   'Essays',
#   'Economics',
#   'Psychology'],
#  ['Fantasy',
#   'Young Adult',
#   'Fiction',
#   'Arthurian',
#   'Magic',
#   'Adventure',
#   'Middle Grade',
#   'Mythology',
#   'Science Fiction Fantasy',
#   'Young Adult Fantasy'],
#  ['Mystery',
#   'Romantic Suspense',
#   'Thriller',
#   'Suspense',
#   'Romance',
#   'Fiction',
#   'Crime',
#   'Contemporary',
#   'Mystery Thriller',
#   'Murder Mystery'],
#  ['Fiction',
#   'Contemporary',
#   'Art',
#   'Adult',
#   'Literary Fiction',
#   'Audiobook',
#   'Adult Fiction',
#   'LGBT',
#   'Novels',
#   'Womens'],
#  ['Manga',
#   'Science Fiction',
#   'Romance',
#   'Graphic Novels',
#   'Comics',
#   'Seinen',
#   'Japanese Literature',
#   'Fiction',
#   'Comics Manga',
#   'Young Adult'],
#  ['History',
#   'Nonfiction',
#   'Science',
#   'World History',
#   'Philosophy',
#   'History Of Science',
#   'Biography',
#   'Historical',
#   'Geography',
#   'Cultural'],
#  ['Mystery',
#   'Fiction',
#   'Thriller',
#   'Crime',
#   'Suspense',
#   'Mystery Thriller',
#   'Audiobook',
#   'Adult',
#   'Murder Mystery',
#   'Romance'],
#  ['Writing',
#   'Film',
#   'Nonfiction',
#   'Reference',
#   'Media Tie In',
#   'Research',
#   'Tv',
#   'Textbooks',
#   'School'],
#  ['Science Fiction',
#   'Fiction',
#   'Fantasy',
#   'Novella',
#   'Young Adult',
#   'Science Fiction Fantasy',
#   'Africa',
#   'Audiobook',
#   'Aliens',
#   'Adult'],
#  ['Nonfiction',
#   'Memoir',
#   'Biography',
#   'Travel',
#   'Spanish Literature',
#   'History',
#   'Biography Memoir',
#   'Latin American',
#   'Autobiography',
#   'Womens'],
#  ['Historical Fiction',
#   'Young Adult',
#   'Romance',
#   'Fantasy',
#   'Historical',
#   'Fiction',
#   'Teen',
#   'Mystery',
#   'Adventure',
#   'Regency'],
#  ['Science Fiction',
#   'Fiction',
#   'Science Fiction Fantasy',
#   'Mystery',
#   'Cyberpunk',
#   'Fantasy',
#   'Speculative Fiction',
#   'Crime',
#   'Dystopia',
#   'Near Future'],
#  ['Gardening',
#   'Nonfiction',
#   'Nature',
#   'Sustainability',
#   'Environment',
#   'Reference',
#   'Food',
#   'Ecology',
#   'Agriculture',
#   'Horticulture'],
#  ['Queer',
#   'Theory',
#   'Gay',
#   'Nonfiction',
#   'Literary Criticism',
#   'Queer Studies'],
#  ['Romance',
#   'Fantasy',
#   'Steampunk',
#   'Paranormal',
#   'Paranormal Romance',
#   'Historical Romance',
#   'Historical',
#   'Adventure',
#   'Historical Fiction',
#   'Fiction'],
#  ['Picture Books',
#   'Childrens',
#   'Fiction',
#   'Classics',
#   'France',
#   'Realistic Fiction',
#   'Dogs',
#   'Animals',
#   'Adventure',
#   'Poetry'],
#  ['Horror',
#   'Young Adult',
#   'Mystery',
#   'Fiction',
#   'Middle Grade',
#   'Childrens',
#   'Ghosts',
#   'Fantasy',
#   'Paranormal',
#   'Ghost Stories'],
#  ['Religion',
#   'Lds',
#   'Nonfiction',
#   'Church',
#   'Spirituality',
#   'Inspirational',
#   'Christian',
#   'Lds Non Fiction',
#   'Faith',
#   'Self Help'],
#  ['Young Adult',
#   'Horror',
#   'Fiction',
#   'Mystery',
#   'Childrens',
#   'Teen',
#   'Thriller',
#   'Paranormal',
#   'Fantasy',
#   'Supernatural'],
#  ['Classics',
#   'Fiction',
#   'Literature',
#   'Adult',
#   'Essays',
#   'School',
#   'Historical Fiction'],
#  ['Young Adult',
#   'LGBT',
#   'Fiction',
#   'Mystery',
#   'Realistic Fiction',
#   'Teen',
#   'Contemporary',
#   'Gay',
#   'Queer',
#   'High School'],
#  ['Young Adult',
#   'Paranormal',
#   'Demons',
#   'Romance',
#   'Fantasy',
#   'Angels',
#   'Paranormal Romance',
#   'Supernatural',
#   'Urban Fantasy',
#   'Magic'],
#  ['Fantasy',
#   'Fiction',
#   'Humor',
#   'Comedy',
#   'Vampires',
#   'Science Fiction Fantasy',
#   'Witches',
#   'Magic',
#   'Audiobook',
#   'Comic Fantasy'],
#  ['Mystery',
#   'Thriller',
#   'Crime',
#   'Fiction',
#   'Suspense',
#   'Mystery Thriller',
#   'Romantic Suspense',
#   'Murder Mystery',
#   'Romance',
#   'Adult'],
#  ['Romance',
#   'Historical Romance',
#   'Clean Romance',
#   'Historical',
#   'Regency',
#   'Historical Fiction',
#   'Mystery',
#   'Fiction',
#   'Regency Romance',
#   'Young Adult'],
#  ['Childrens',
#   'Classics',
#   'Fiction',
#   'Animals',
#   'Fantasy',
#   'Nature',
#   'Picture Books',
#   'Chapter Books',
#   'Juvenile',
#   '2nd Grade'],
#  ['Art',
#   'Nonfiction',
#   'Art History',
#   'History',
#   'Museums',
#   'Memoir',
#   'Biography',
#   'Museology',
#   'New York',
#   'Biography Memoir'],
#  ['New Adult',
#   'Romance',
#   'Abuse',
#   'Contemporary Romance',
#   'Contemporary',
#   'Erotica',
#   'Dark',
#   'Amazon',
#   'Young Adult',
#   'Fiction'],
#  ['Fiction',
#   'Chick Lit',
#   'Contemporary',
#   'Romance',
#   'The United States Of America',
#   'Adult',
#   'Novels',
#   'Love',
#   'American',
#   'Literary Fiction'],
#  ['Middle Grade', 'Realistic Fiction', '2nd Grade', 'Childrens', 'Kids'],
#  ['Classics',
#   'Fiction',
#   'Short Stories',
#   'Childrens',
#   'Fantasy',
#   'Animals',
#   'Adventure',
#   'India',
#   'Literature',
#   'Audiobook'],
#  ['Fiction',
#   'Chick Lit',
#   'Romance',
#   'Contemporary',
#   'Adult',
#   'Adult Fiction',
#   'Family',
#   'Drama',
#   'Audiobook',
#   'Womens Fiction'],
#  ['Chick Lit',
#   'Fiction',
#   'Romance',
#   'Contemporary',
#   'Ireland',
#   'Adult',
#   'Irish Literature',
#   'Contemporary Romance',
#   'Humor',
#   'Adult Fiction'],
#  ['Horror',
#   'Fiction',
#   'Thriller',
#   'Suspense',
#   'Mystery',
#   'Novels',
#   'Adult',
#   'Mystery Thriller',
#   'Crime',
#   'Drama'],
#  ['Fantasy',
#   'Young Adult',
#   'Romance',
#   'Fairy Tales',
#   'Magic',
#   'Time Travel',
#   'Chick Lit',
#   'Fiction',
#   'Adventure',
#   'Humor'],
#  ['Philosophy',
#   'Theory',
#   'Politics',
#   'Nonfiction',
#   'Italian Literature',
#   'Theology',
#   'Italy',
#   'Sociology',
#   'Essays',
#   'Religion'],
#  ...]

# %% [markdown]
# ## Run Association Rules with the current Data

# %%
pd.set_option('display.max_rows', 20)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
# Codificación de las transacciones
encoder = TransactionEncoder()
encoder_array = encoder.fit_transform(transactions)
df = pd.DataFrame(encoder_array, columns=encoder.columns_)

# Aplicar Apriori
frequent_itemsets = apriori(df, min_support=0.3, use_colnames=True)
frequent_itemsets

# Reglas de asociación
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.1)
rules.sort_values("confidence", ascending=False)
# Out:
#   antecedents consequents  antecedent support  consequent support   support  confidence     lift  leverage  conviction  zhangs_metric
# 1   (Fantasy)   (Fiction)            0.336341            0.721822  0.303235    0.901570  1.24902  0.060457    2.826159       0.300414
# 0   (Fiction)   (Fantasy)            0.721822            0.336341  0.303235    0.420097  1.24902  0.060457    1.144430       0.716708

# %%
df.sum().sort_values(ascending=False)
# Out:
# Fiction         22959
# Fantasy         10698
# Romance          9237
# Young Adult      8330
# Contemporary     6342
#                 ...
# Museology           1
# Muslimah            1
# NSFW                1
# Namibia             1
# 漫画                  1
# Length: 944, dtype: int64

# %%
# rules[(rules['confidence'] < 1.0)].sort_values("confidence", ascending=False)
rules['antecedent_len'] = rules['antecedents'].apply(lambda x: len(x))
filtered_rules = rules[rules['antecedent_len'] >= 3]
filtered_rules[filtered_rules['confidence'] < 1].sort_values("confidence", ascending=False)
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction, zhangs_metric, antecedent_len]
# Index: []
